# %% [markdown]
# # Quick overview
#
# This Notebook provides a quick overview for using the potentials package to explore and access interatomic potentials hosted by the NIST Interatomic Potentials Repository (IPR).  More advanced users can check the subsequent Notebooks for more details and the various options that are available.

# %%
# Standard Python libraries
from pathlib import Path
import time

# https://github.com/lmhale99/potentials
import potentials

print('Notebook tested for potentials version', potentials.__version__)
# Out:
# Notebook tested for potentials version 0.4.0

# %% [markdown]
# ## 1. Initialize database connections
#
# When initializing a potentials.Database object, the default behavior is to connect with two database locations for exploring stored records:
#
# - __local__ being a local directory containing JSON or XML records, which allows for user-defined and offline entries to be stored.
# - __remote__ being https://potentials.nist.gov, where the current NIST entries can be found.

# %%
potdb = potentials.Database()

# %% [markdown]
# ## 2. Potential listings
#
# The Potential record style stores the listing information for the NIST-hosted potentials as they appear on the [NIST Interatomic Potentials Repository](https://www.ctcms.nist.gov/potentials/).  Querying these records provides a quick and convenient means of searching and exploring information about the hosted interatomic potentials.
#
# ### 2.1. Query potentials
#
# Potential listings can be queried using the __get_potentials()__ or __get_potential()__ methods.  The plural method will return all matching records, whereas the singular method is designed to return only one matching record.

# %% [markdown]
# Get all potential listings with a citation from 2004.  Setting verbose=True will print informative messages about the operations being performed.

# %%
pots, pot_df = potdb.get_potentials(return_df=True, verbose=True, year='2004')
# Out:
# Found 23 matching Potential records in local library
# 100%|███████████████████████████████████████████████████████████████████████████████████| 24/24 [00:22<00:00,  1.63s/it]
# Found 24 matching Potential records in remote library
#  - 1 remote records are new

# %% [markdown]
# The function returns all matching record objects

# %%
for pot in pots:
    print(pot.id)
# Out:
# 2004--Ackland-G-J-Mendelev-M-I-Srolovitz-D-J-et-al--Fe-P
# 2004--Bailey-N-P-Schiotz-J-Jacobsen-K-W--Cu-Mg
# 2004--Lee-B-J-Shim-J-H--Cu-Ni
# 2004--Liu-X-Y-Ercolessi-F-Adams-J-B--Al
# 2004--Mishin-Y--Ni-Al
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Ag
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Al
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Au
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Co
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Cu
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Cu-Ag-Au
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Cu-Ag-Au-Ni-Pd-Pt-Al-Pb-Fe-Mo-Ta-W-Mg-Co-Ti-Zr
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Fe
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Mg
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Mo
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Ni
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Pb
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Pd
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Pt
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Ta
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Ta-Cu
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Ti
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--W
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Zr

# %% [markdown]
# With return_df=True in the get_potentials() call, a pandas DataFrame of the records' simple metadata fields is also returned.

# %%
pot_df
# Out:
#                                                  name  \
# 0   potential.2004--Ackland-G-J-Mendelev-M-I-Srolo...
# 1   potential.2004--Bailey-N-P-Schiotz-J-Jacobsen-...
# 2             potential.2004--Lee-B-J-Shim-J-H--Cu-Ni
# 3   potential.2004--Liu-X-Y-Ercolessi-F-Adams-J-B--Al
# 4                     potential.2004--Mishin-Y--Ni-Al
# 5   potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 6   potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 7   potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 8   potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 9   potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 10  potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 11  potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 12  potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 13  potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 14  potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 15  potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 16  potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 17  potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 18  potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 19  potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 20  potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 21  potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 22  potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 23  potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
#
#                                      key  \
# 0   5793213a-63e3-43de-84c4-c20e5a3902ec
# 1   120a3b51-6110-4061-84df-f790598647dc
# 2   f945bbd5-8490-457d-a363-cb1bd4267293
# 3   8f71b887-b4c5-42c0-b06c-9456153725d9
# 4   13051c1b-48f7-47f5-bad7-fc627fe10376
# 5   248c41b3-6861-43d0-876c-e528541b699f
# 6   5aad5c57-cd85-48b3-acb0-db0cc4f68e31
# 7   56c064d6-9bb4-42b6-b5e1-b54bb4dbae1d
# 8   86bc9f81-1601-4a4f-bcc1-f5d7d96c3e9b
# 9   2b5389d5-0313-43be-a7c7-ce9130ba51b8
# 10  52da31b9-68f7-4c14-9e82-048f6fbdd145
# 11  ea0e3268-af73-4ecf-8fab-c55ba2fb33af
# 12  030d9099-cf7f-4623-b597-733e80d214a4
# 13  816ed50d-9e0c-4bd2-8a9a-dca83d4e0bb8
# 14  7447a36d-7f5c-4562-b569-825d3cf66cc1
# 15  063c9331-69e4-40e4-bb6c-cee56d576b60
# 16  1c592eb1-3cdd-4090-aa0b-e7246f7d5f91
# 17  5ea5dd6c-a901-4acd-b036-9c33a0acd5b0
# 18  b236a7be-023c-4df7-8146-da4fbdfcf900
# 19  04aa4a53-9229-4c6a-8a03-1e8836fd8712
# 20  f12498d1-1560-4fcf-af65-7ec9934b0b95
# 21  8d877089-5fc2-418e-a2b3-a1b468483690
# 22  865a32b5-d4ae-4e3e-bd8b-b503d0ba1a78
# 23  6ccabaad-9825-4d97-9f9d-3058fca15806
#
#                                                    id  \
# 0   2004--Ackland-G-J-Mendelev-M-I-Srolovitz-D-J-e...
# 1      2004--Bailey-N-P-Schiotz-J-Jacobsen-K-W--Cu-Mg
# 2                       2004--Lee-B-J-Shim-J-H--Cu-Ni
# 3             2004--Liu-X-Y-Ercolessi-F-Adams-J-B--Al
# 4                               2004--Mishin-Y--Ni-Al
# 5         2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Ag
# 6         2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Al
# 7         2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Au
# 8         2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Co
# 9         2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Cu
# 10  2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Cu-Ag-Au
# 11  2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Cu-Ag...
# 12        2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Fe
# 13        2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Mg
# 14        2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Mo
# 15        2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Ni
# 16        2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Pb
# 17        2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Pd
# 18        2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Pt
# 19        2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Ta
# 20     2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Ta-Cu
# 21        2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Ti
# 22         2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--W
# 23        2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Zr
#
#                                                   url  recorddate  \
# 0   https://potentials.nist.gov/pid/rest/local/pot...  2018-10-05
# 1   https://potentials.nist.gov/pid/rest/local/pot...  2020-10-08
# 2   https://potentials.nist.gov/pid/rest/local/pot...  2020-10-15
# 3   https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 4   https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 5   https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 6   https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 7   https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 8   https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 9   https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 10  https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 11  https://potentials.nist.gov/pid/rest/local/pot...  2024-04-04
# 12  https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 13  https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 14  https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 15  https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 16  https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 17  https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 18  https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 19  https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 20  https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 21  https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 22  https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 23  https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
#
#                                             citations  \
# 0   [{'doctype': 'journal', 'title': 'Development ...
# 1   [{'doctype': 'journal', 'title': 'Simulation o...
# 2   [{'doctype': 'journal', 'title': 'A modified e...
# 3   [{'doctype': 'journal', 'title': 'Aluminium in...
# 4   [{'doctype': 'journal', 'title': 'Atomistic mo...
# 5   [{'doctype': 'journal', 'title': 'Misfit-energ...
# 6   [{'doctype': 'journal', 'title': 'Misfit-energ...
# 7   [{'doctype': 'journal', 'title': 'Misfit-energ...
# 8   [{'doctype': 'journal', 'title': 'Misfit-energ...
# 9   [{'doctype': 'journal', 'title': 'Misfit-energ...
# 10  [{'doctype': 'journal', 'title': 'Misfit-energ...
# 11  [{'doctype': 'journal', 'title': 'Misfit-energ...
# 12  [{'doctype': 'journal', 'title': 'Misfit-energ...
# 13  [{'doctype': 'journal', 'title': 'Misfit-energ...
# 14  [{'doctype': 'journal', 'title': 'Misfit-energ...
# 15  [{'doctype': 'journal', 'title': 'Misfit-energ...
# 16  [{'doctype': 'journal', 'title': 'Misfit-energ...
# 17  [{'doctype': 'journal', 'title': 'Misfit-energ...
# 18  [{'doctype': 'journal', 'title': 'Misfit-energ...
# 19  [{'doctype': 'journal', 'title': 'Misfit-energ...
# 20  [{'doctype': 'journal', 'title': 'Misfit-energ...
# 21  [{'doctype': 'journal', 'title': 'Misfit-energ...
# 22  [{'doctype': 'journal', 'title': 'Misfit-energ...
# 23  [{'doctype': 'journal', 'title': 'Misfit-energ...
#
#                                                 notes  \
# 0                                                 NaN
# 1   This model implements a special parametrizatio...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  This is a combined potential that contains all...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
#
#                                       implementations fictionalelements  \
# 0   [{'key': '42b9318c-4d62-4af9-a7ea-d8bd05b5f79b...               NaN
# 1   [{'key': 'cb4da6b3-bd9a-4a34-b296-4c3bd994a977...               NaN
# 2   [{'key': 'b36a160c-db24-4b64-9779-b2702fde8a10...               NaN
# 3   [{'key': 'e8cb5f73-c704-4630-ab37-38692f9c1767...               NaN
# 4   [{'key': '239e4f9a-145d-4c93-a967-73fb3ba28fea...               NaN
# 5   [{'key': 'c29118aa-758e-424f-b272-1a03eb7e9243...               NaN
# 6   [{'key': '1f7e92f1-daa4-4d77-85dc-5cd8071d4b4f...               NaN
# 7   [{'key': '6ec19f45-c243-4873-829b-1146de3844f8...               NaN
# 8   [{'key': 'add827af-0ac0-435c-b9b0-10d1511349a2...               NaN
# 9   [{'key': '7327569b-111a-43b5-b8ec-5a5a4630e85c...               NaN
# 10  [{'key': 'b3047b49-4837-49e8-b65c-5c2fc349ac4a...               NaN
# 11  [{'key': '066dd206-3d44-46f9-ace0-5cf4a93977b1...              None
# 12  [{'key': '4008a8a9-587d-4773-8ed3-5d89448c7e22...               NaN
# 13  [{'key': '34ca874a-6213-4054-8ddf-2ed9ecfc371b...               NaN
# 14  [{'key': 'cedfe232-45cb-4b57-bc7b-1c9f0abcb9c1...               NaN
# 15  [{'key': 'ea7a735e-e004-42eb-8194-c5475617eb4f...               NaN
# 16  [{'key': 'd7544c5b-4266-45d4-9566-e45eedfe56de...               NaN
# 17  [{'key': '360a78a7-1956-4ae4-9f2d-c2a401b5f303...               NaN
# 18  [{'key': 'a24bb1b4-6943-47a2-92d1-ce3dc4c5e4fd...               NaN
# 19  [{'key': 'd7a01a87-ef01-43e5-8a42-266b4b75f0a1...               NaN
# 20  [{'key': '3fc3e5ae-e794-4759-8634-dab9be699c3e...               NaN
# 21  [{'key': 'ab0c2824-38b5-4836-80df-bc6b25710aed...               NaN
# 22  [{'key': '5667afd5-7957-4901-a931-72a77f67eb5c...               NaN
# 23  [{'key': '781c611a-326e-4e9f-a8ac-2b173310f702...               NaN
#
#                                              elements othername  \
# 0                                             [Fe, P]       NaN
# 1                                            [Cu, Mg]       NaN
# 2                                            [Cu, Ni]       NaN
# 3                                                [Al]       NaN
# 4                                            [Ni, Al]       NaN
# 5                                                [Ag]       NaN
# 6                                                [Al]       NaN
# 7                                                [Au]       NaN
# 8                                                [Co]       NaN
# 9                                                [Cu]       NaN
# 10                                       [Cu, Ag, Au]       NaN
# 11  [Cu, Ag, Au, Ni, Pd, Pt, Al, Pb, Fe, Mo, Ta, W...      None
# 12                                               [Fe]       NaN
# 13                                               [Mg]       NaN
# 14                                               [Mo]       NaN
# 15                                               [Ni]       NaN
# 16                                               [Pb]       NaN
# 17                                               [Pd]       NaN
# 18                                               [Pt]       NaN
# 19                                               [Ta]       NaN
# 20                                           [Ta, Cu]       NaN
# 21                                               [Ti]       NaN
# 22                                                [W]       NaN
# 23                                               [Zr]       NaN
#
#                                              surnames
# 0       [Ackland, Mendelev, Srolovitz, Han, Barashev]
# 1   [Bailey, Schiøtz, Jacobsen, Bailey, Schiøtz, J...
# 2                                         [Lee, Shim]
# 3                             [Liu, Ercolessi, Adams]
# 4                                            [Mishin]
# 5                             [Zhou, Johnson, Wadley]
# 6                             [Zhou, Johnson, Wadley]
# 7                             [Zhou, Johnson, Wadley]
# 8                             [Zhou, Johnson, Wadley]
# 9                             [Zhou, Johnson, Wadley]
# 10                            [Zhou, Johnson, Wadley]
# 11                            [Zhou, Johnson, Wadley]
# 12                            [Zhou, Johnson, Wadley]
# 13                            [Zhou, Johnson, Wadley]
# 14                            [Zhou, Johnson, Wadley]
# 15                            [Zhou, Johnson, Wadley]
# 16                            [Zhou, Johnson, Wadley]
# 17                            [Zhou, Johnson, Wadley]
# 18                            [Zhou, Johnson, Wadley]
# 19                            [Zhou, Johnson, Wadley]
# 20                            [Zhou, Johnson, Wadley]
# 21                            [Zhou, Johnson, Wadley]
# 22                            [Zhou, Johnson, Wadley]
# 23                            [Zhou, Johnson, Wadley]

# %% [markdown]
# ### 2.2. Further parsing after query
#
# Having the DataFrame alongside the Potential objects is useful as it allows for further parsing and sorting of the records without needing to perform another query.

# %%
def element_filter(series, element):
    """pandas.DataFrame apply function for finding records which contain a specific element"""
    return element in series.elements

al_pot_df = pot_df[pot_df.apply(element_filter, axis=1, args=['Al'])]
al_pot_df
# Out:
#                                                  name  \
# 3   potential.2004--Liu-X-Y-Ercolessi-F-Adams-J-B--Al
# 4                     potential.2004--Mishin-Y--Ni-Al
# 6   potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 11  potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
#
#                                      key  \
# 3   8f71b887-b4c5-42c0-b06c-9456153725d9
# 4   13051c1b-48f7-47f5-bad7-fc627fe10376
# 6   5aad5c57-cd85-48b3-acb0-db0cc4f68e31
# 11  ea0e3268-af73-4ecf-8fab-c55ba2fb33af
#
#                                                    id  \
# 3             2004--Liu-X-Y-Ercolessi-F-Adams-J-B--Al
# 4                               2004--Mishin-Y--Ni-Al
# 6         2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Al
# 11  2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Cu-Ag...
#
#                                                   url  recorddate  \
# 3   https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 4   https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 6   https://potentials.nist.gov/pid/rest/local/pot...  2018-08-15
# 11  https://potentials.nist.gov/pid/rest/local/pot...  2024-04-04
#
#                                             citations  \
# 3   [{'doctype': 'journal', 'title': 'Aluminium in...
# 4   [{'doctype': 'journal', 'title': 'Atomistic mo...
# 6   [{'doctype': 'journal', 'title': 'Misfit-energ...
# 11  [{'doctype': 'journal', 'title': 'Misfit-energ...
#
#                                                 notes  \
# 3                                                 NaN
# 4                                                 NaN
# 6                                                 NaN
# 11  This is a combined potential that contains all...
#
#                                       implementations fictionalelements  \
# 3   [{'key': 'e8cb5f73-c704-4630-ab37-38692f9c1767...               NaN
# 4   [{'key': '239e4f9a-145d-4c93-a967-73fb3ba28fea...               NaN
# 6   [{'key': '1f7e92f1-daa4-4d77-85dc-5cd8071d4b4f...               NaN
# 11  [{'key': '066dd206-3d44-46f9-ace0-5cf4a93977b1...              None
#
#                                              elements othername  \
# 3                                                [Al]       NaN
# 4                                            [Ni, Al]       NaN
# 6                                                [Al]       NaN
# 11  [Cu, Ag, Au, Ni, Pd, Pt, Al, Pb, Fe, Mo, Ta, W...      None
#
#                    surnames
# 3   [Liu, Ercolessi, Adams]
# 4                  [Mishin]
# 6   [Zhou, Johnson, Wadley]
# 11  [Zhou, Johnson, Wadley]

# %% [markdown]
# The Potential objects are returned in a numpy array so the same index filtering used on the dataframe can be applied to the records.

# %%
for pot in pots[pot_df.apply(element_filter, axis=1, args=['Al'])]:
    print(pot.id)
# Out:
# 2004--Liu-X-Y-Ercolessi-F-Adams-J-B--Al
# 2004--Mishin-Y--Ni-Al
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Al
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Cu-Ag-Au-Ni-Pd-Pt-Al-Pb-Fe-Mo-Ta-W-Mg-Co-Ti-Zr

# %% [markdown]
# Alternatively, the index values of a DataFrame slice can be used on the array of objects to retrieve the corresponding ones.

# %%
for pot in pots[al_pot_df.index]:
    print(pot.id)
# Out:
# 2004--Liu-X-Y-Ercolessi-F-Adams-J-B--Al
# 2004--Mishin-Y--Ni-Al
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Al
# 2004--Zhou-X-W-Johnson-R-A-Wadley-H-N-G--Cu-Ag-Au-Ni-Pd-Pt-Al-Pb-Fe-Mo-Ta-W-Mg-Co-Ti-Zr

# %% [markdown]
# ### 2.3. Display entries
#
# Each potential record object also has an html method that allows for the record to be rendered as it appears on the IPR website. Setting render=True allows for a Jupyter Notebook to automatically render the html content as it should appear.  Otherwise, if render=False, then a str of the html code is returned.

# %%
# Generate HTML for the first of the 2004 Al records
pots[al_pot_df.index][0].html(render=True)
# Out:
# <div xmlns="http://www.w3.org/TR/xhtml1/strict"><script src="https://www.ctcms.nist.gov/potentials/site/showFiles.js">//</script><div class="panel panel-default"><div class="panel-heading"><h3 class="panel-title">2004--Liu-X-Y-Ercolessi-F-Adams-J-B--Al</h3></div><div class="panel-body"><div class="citation"><b>Citation: </b>X.-Y. Liu, F. Ercolessi, and J.B. Adams (2004), "Aluminium interatomic potential from density functional theory calculations with improved stacking fault energy", <i>Modelling and Simulation in Materials Science and Engineering</i>, <b>12(4)</b>, 665-670. DOI: <a href="https://doi.org/10.1088/0965-0393/12/4/007" class="external">10.1088/0965-0393/12/4/007</a>.<br/></div><div class="abstract"><b>Abstract: </b>A new Al potential with improved stacking fault energy is constructed using the force-matching method. The potential is fitted to an ab initio forces database and various experimental data. By using a slightly larger cut-off, we found that the new potential gives the relaxed stacking fault energy in the experimental range without changing the excellent thermal and surface properties of the original force-matching Al potential given by Ercolessi and Adams (1994 Europhys. Lett. 26 583).</div><br/><div class="format"><b>EAM setfl</b><a href="https://www.ctcms.nist.gov/potentials/entry/2004--Liu-X-Y-Ercolessi-F-Adams-J-B--Al/2004--Liu-X-Y--Al--table--ipr1.html"> (2004--Liu-X-Y--Al--table--ipr1)</a></div><div class="implementation-notes"><a href="https://www.ctcms.nist.gov/potentials/entry/2004--Liu-X-Y-Ercolessi-F-Adams-J-B--Al/2004--Liu-X-Y--Al--table--ipr1.html"><b>See Computed Properties</b></a><br/><b>Notes: </b>NEWAl.txt was obtained from <a href="http://enpub.fulton.asu.edu/cms/potentials/main/main.htm" class="external">http://enpub.fulton.asu.edu/cms/potentials/main/main.htm</a> and posted with the permission of J.B. Adams.<br/><b>File(s): </b><div id="e8cb5f73-c704-4630-ab37-38692f9c1767" style="display:block"><a href="https://www.ctcms.nist.gov/potentials/Download/2004--Liu-X-Y-Ercolessi-F-Adams-J-B--Al/1/NEWAl.txt">NEWAl.txt</a><br/></div><br/></div><div class="format"><b>LAMMPS pair_style eam/alloy</b><a href="https://www.ctcms.nist.gov/potentials/entry/2004--Liu-X-Y-Ercolessi-F-Adams-J-B--Al/2004--Liu-X-Y--Al--LAMMPS--ipr1.html"> (2004--Liu-X-Y--Al--LAMMPS--ipr1)</a></div><div class="implementation-notes"><a href="https://www.ctcms.nist.gov/potentials/entry/2004--Liu-X-Y-Ercolessi-F-Adams-J-B--Al/2004--Liu-X-Y--Al--LAMMPS--ipr1.html"><b>See Computed Properties</b></a><br/><b>Notes: </b>Al-LEA.eam.alloy is a version of the same potential which has been formatted for use in LAMMPS ("D" was replaced by "e", "FCC" by "fcc", and "Al" was added on line 3).<br/><b>File(s): </b><div id="41aaa580-48b9-4036-aaa9-66e5234edb9f" style="display:block"><a href="https://www.ctcms.nist.gov/potentials/Download/2004--Liu-X-Y-Ercolessi-F-Adams-J-B--Al/2/Al-LEA.eam.alloy">Al-LEA.eam.alloy</a><br/></div><br/></div><div class="format"><b>OpenKIM</b><a href="https://www.ctcms.nist.gov/potentials/entry/2004--Liu-X-Y-Ercolessi-F-Adams-J-B--Al/MO_051157671505.html"> (MO_051157671505)</a></div><div class="implementation-notes"><a href="https://www.ctcms.nist.gov/potentials/entry/2004--Liu-X-Y-Ercolessi-F-Adams-J-B--Al/MO_051157671505.html"><b>See Computed Properties</b></a><br/><b>Notes: </b>Listing found at https://openkim.org.  This KIM potential is based on the files from 2004--Liu-X-Y--Al--LAMMPS--ipr1.<br/><b>Link(s): </b><div id="4532953e-2a22-4cf4-bf99-2aad6741382a" style="display:block">KIM page <a href="https://openkim.org/id/EAM_Dynamo_LiuErcolessiAdams_2004_Al__MO_051157671505_000">EAM_Dynamo_LiuErcolessiAdams_2004_Al__MO_051157671505_000</a><br/></div><br/></div></div></div></div>

# %% [markdown]
# ## 3.  LAMMPS potentials
#
# Records associated with LAMMPS potentials are also stored in the database.  The LAMMPS potential records allow for any associated parameter files to be automatically downloaded and for the correct LAMMPS pair_style and pair_coeff command lines to be generated.
#
# ### 3.1. Query LAMMPS potentials
#
# Similar to the potentials listings, the available LAMMPS implementations can be explored using the __get_lammps_potentials()__ and __get_lammps_potential()__ methods.

# %% [markdown]
# Example of getting all LAMMPS potentials with the classic eam LAMMPS pair_style.

# %%
lmppots, lmppots_df = potdb.get_lammps_potentials(pair_style='eam', return_df=True, verbose=True, pot_dir_style='working')
lmppots_df
# Out:
# Found 17 matching potential_LAMMPS records in local library
# 100%|███████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 23.92it/s]
# Found 17 matching potential_LAMMPS records in remote library
#  - 0 remote records are new
# Found 0 matching potential_LAMMPS_KIM records in local library
# Found 0 matching potential_LAMMPS_KIM records in remote library
# Built 0 lammps potentials for KIM models
#                                                  name  \
# 0               1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1
# 1                  1986--Foiles-S-M--Ag--LAMMPS--ipr1
# 2   1986--Foiles-S-M--Ag-Au-Cu-Ni-Pd-Pt--LAMMPS--ipr1
# 3                  1986--Foiles-S-M--Au--LAMMPS--ipr1
# 4                  1986--Foiles-S-M--Cu--LAMMPS--ipr1
# 5                  1986--Foiles-S-M--Ni--LAMMPS--ipr1
# 6                  1986--Foiles-S-M--Pd--LAMMPS--ipr1
# 7                  1986--Foiles-S-M--Pt--LAMMPS--ipr1
# 8                   1989--Adams-J-B--Ag--LAMMPS--ipr1
# 9    1989--Adams-J-B--Ag-Au-Cu-Ni-Pd-Pt--LAMMPS--ipr1
# 10                  1989--Adams-J-B--Au--LAMMPS--ipr1
# 11                  1989--Adams-J-B--Cu--LAMMPS--ipr1
# 12                  1989--Adams-J-B--Ni--LAMMPS--ipr1
# 13                  1989--Adams-J-B--Pd--LAMMPS--ipr1
# 14                  1989--Adams-J-B--Pt--LAMMPS--ipr1
# 15                    1998--Meyer-R--Fe--LAMMPS--ipr1
# 16             2003--Mendelev-M-I--Fe-2--LAMMPS--ipr2
#
#                                                    id  \
# 0               1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1
# 1                  1986--Foiles-S-M--Ag--LAMMPS--ipr1
# 2   1986--Foiles-S-M--Ag-Au-Cu-Ni-Pd-Pt--LAMMPS--ipr1
# 3                  1986--Foiles-S-M--Au--LAMMPS--ipr1
# 4                  1986--Foiles-S-M--Cu--LAMMPS--ipr1
# 5                  1986--Foiles-S-M--Ni--LAMMPS--ipr1
# 6                  1986--Foiles-S-M--Pd--LAMMPS--ipr1
# 7                  1986--Foiles-S-M--Pt--LAMMPS--ipr1
# 8                   1989--Adams-J-B--Ag--LAMMPS--ipr1
# 9    1989--Adams-J-B--Ag-Au-Cu-Ni-Pd-Pt--LAMMPS--ipr1
# 10                  1989--Adams-J-B--Au--LAMMPS--ipr1
# 11                  1989--Adams-J-B--Cu--LAMMPS--ipr1
# 12                  1989--Adams-J-B--Ni--LAMMPS--ipr1
# 13                  1989--Adams-J-B--Pd--LAMMPS--ipr1
# 14                  1989--Adams-J-B--Pt--LAMMPS--ipr1
# 15                    1998--Meyer-R--Fe--LAMMPS--ipr1
# 16             2003--Mendelev-M-I--Fe-2--LAMMPS--ipr2
#
#                                      key  \
# 0   062d2ba7-3903-40ae-a772-daa471d107c6
# 1   76a265fc-45ff-49d7-8c64-2044f12402f2
# 2   c5afa7e8-6b3b-49cd-ad1c-ae3e4329363a
# 3   c588810a-b96d-4871-bfe2-cff8a5a7c709
# 4   380d3b47-51e9-4590-8a59-8313dd8fb018
# 5   8e9ae12d-5034-418a-a168-fb5499ecffcd
# 6   fa189ff3-4a27-4c36-b8b7-3821443a4edd
# 7   0a74d2a8-ec49-459c-903a-44bd3e50969a
# 8   cbe0bfac-4e4c-49e4-91a4-e6d360ff0516
# 9   8a99e4c9-7a90-4c0e-96f5-57048066940f
# 10  ee3495e7-e36a-418e-9de3-c5ef4643ef7f
# 11  ddb93f7b-349f-4ab2-a630-97de04d12eff
# 12  27a40f2f-0c18-417d-81cc-97b788bcecf7
# 13  a5486f00-b393-45af-9b99-c841d2615563
# 14  945f91fc-e7d9-40d6-bb03-b147036c19d8
# 15  cfd40828-6e93-446d-b419-fe59118a5683
# 16  d7065ba6-3386-4793-9ab9-6a5d83c4fa25
#
#                                      url  \
# 0   062d2ba7-3903-40ae-a772-daa471d107c6
# 1   76a265fc-45ff-49d7-8c64-2044f12402f2
# 2   c5afa7e8-6b3b-49cd-ad1c-ae3e4329363a
# 3   c588810a-b96d-4871-bfe2-cff8a5a7c709
# 4   380d3b47-51e9-4590-8a59-8313dd8fb018
# 5   8e9ae12d-5034-418a-a168-fb5499ecffcd
# 6   fa189ff3-4a27-4c36-b8b7-3821443a4edd
# 7   0a74d2a8-ec49-459c-903a-44bd3e50969a
# 8   cbe0bfac-4e4c-49e4-91a4-e6d360ff0516
# 9   8a99e4c9-7a90-4c0e-96f5-57048066940f
# 10  ee3495e7-e36a-418e-9de3-c5ef4643ef7f
# 11  ddb93f7b-349f-4ab2-a630-97de04d12eff
# 12  27a40f2f-0c18-417d-81cc-97b788bcecf7
# 13  a5486f00-b393-45af-9b99-c841d2615563
# 14  945f91fc-e7d9-40d6-bb03-b147036c19d8
# 15  cfd40828-6e93-446d-b419-fe59118a5683
# 16  d7065ba6-3386-4793-9ab9-6a5d83c4fa25
#
#                                                 potid  \
# 0                             1985--Foiles-S-M--Ni-Cu
# 1             1986--Foiles-S-M-Baskes-M-I-Daw-M-S--Ag
# 2   1986--Foiles-S-M-Baskes-M-I-Daw-M-S--Ag-Au-Cu-...
# 3             1986--Foiles-S-M-Baskes-M-I-Daw-M-S--Au
# 4             1986--Foiles-S-M-Baskes-M-I-Daw-M-S--Cu
# 5             1986--Foiles-S-M-Baskes-M-I-Daw-M-S--Ni
# 6             1986--Foiles-S-M-Baskes-M-I-Daw-M-S--Pd
# 7             1986--Foiles-S-M-Baskes-M-I-Daw-M-S--Pt
# 8           1989--Adams-J-B-Foiles-S-M-Wolfer-W-G--Ag
# 9   1989--Adams-J-B-Foiles-S-M-Wolfer-W-G--Ag-Au-C...
# 10          1989--Adams-J-B-Foiles-S-M-Wolfer-W-G--Au
# 11          1989--Adams-J-B-Foiles-S-M-Wolfer-W-G--Cu
# 12          1989--Adams-J-B-Foiles-S-M-Wolfer-W-G--Ni
# 13          1989--Adams-J-B-Foiles-S-M-Wolfer-W-G--Pd
# 14          1989--Adams-J-B-Foiles-S-M-Wolfer-W-G--Pt
# 15                          1998--Meyer-R-Entel-P--Fe
# 16  2003--Mendelev-M-I-Han-S-Srolovitz-D-J-et-al--...
#
#                                   potkey poturl  units atom_style  allsymbols  \
# 0   301f04ce-9082-4542-8590-489300cd19e8    NaN  metal     atomic         0.0
# 1   672d54f8-9f48-4200-af56-8a7378ebbc4a    NaN  metal     atomic         0.0
# 2   7a1302de-59cf-4efb-900e-cad845b68ee5    NaN  metal     atomic         0.0
# 3   ffb66faa-319d-4556-8363-dad3959cd553    NaN  metal     atomic         0.0
# 4   7991d330-58cd-43ac-bba9-ff6a58dcf617    NaN  metal     atomic         0.0
# 5   15a085b9-d9d6-404f-9c2f-3ed40e8ff7a4    NaN  metal     atomic         0.0
# 6   16dde7ea-c8cf-4a23-95b3-494a2b252e9b    NaN  metal     atomic         0.0
# 7   87657840-e5e6-4378-94ea-381a90608142    NaN  metal     atomic         0.0
# 8   d1e36148-f138-4ee0-ab7d-1fb5442805d8    NaN  metal     atomic         0.0
# 9   9ddb10de-d3f8-43fe-9dfc-472d704537e1    NaN  metal     atomic         0.0
# 10  8018facc-a337-4e34-b13f-b293f36a3458    NaN  metal     atomic         0.0
# 11  69d9f89a-f9a2-47ef-bd15-415d1bb7a9ba    NaN  metal     atomic         0.0
# 12  e4cf8356-8b84-4e07-ac2b-580419a21730    NaN  metal     atomic         0.0
# 13  d43c300c-e557-42f8-87a0-c26cf82370df    NaN  metal     atomic         0.0
# 14  6f92bdbe-0eea-4865-ac81-888e522b6a90    NaN  metal     atomic         0.0
# 15  bfd028cc-3a49-4a21-9731-56cee899c095    NaN  metal     atomic         0.0
# 16  06bf7ccd-ea6a-4744-bfbc-adefa5bcdd60    NaN  metal     atomic         0.0
#
#    pair_style     status                   symbols                  elements  \
# 0         eam     active                  [Cu, Ni]                  [Cu, Ni]
# 1         eam     active                      [Ag]                      [Ag]
# 2         eam     active  [Ag, Au, Cu, Ni, Pd, Pt]  [Ag, Au, Cu, Ni, Pd, Pt]
# 3         eam     active                      [Au]                      [Au]
# 4         eam     active                      [Cu]                      [Cu]
# 5         eam     active                      [Ni]                      [Ni]
# 6         eam     active                      [Pd]                      [Pd]
# 7         eam     active                      [Pt]                      [Pt]
# 8         eam     active                      [Ag]                      [Ag]
# 9         eam     active  [Ag, Au, Cu, Ni, Pd, Pt]  [Ag, Au, Cu, Ni, Pd, Pt]
# 10        eam     active                      [Au]                      [Au]
# 11        eam     active                      [Cu]                      [Cu]
# 12        eam     active                      [Ni]                      [Ni]
# 13        eam     active                      [Pd]                      [Pd]
# 14        eam     active                      [Pt]                      [Pt]
# 15        eam     active                      [Fe]                      [Fe]
# 16        eam  retracted                      [Fe]                      [Fe]
#
#                                             artifacts  \
# 0   [{'filename': 'Cu_smf7.eam', 'label': None, 'u...
# 1   [{'filename': 'Ag_u3.eam', 'label': None, 'url...
# 2   [{'filename': 'Ag_u3.eam', 'label': None, 'url...
# 3   [{'filename': 'Au_u3.eam', 'label': None, 'url...
# 4   [{'filename': 'Cu_u3.eam', 'label': None, 'url...
# 5   [{'filename': 'Ni_u3.eam', 'label': None, 'url...
# 6   [{'filename': 'Pd_u3.eam', 'label': None, 'url...
# 7   [{'filename': 'Pt_u3.eam', 'label': None, 'url...
# 8   [{'filename': 'agu6.txt', 'label': None, 'url'...
# 9   [{'filename': 'agu6.txt', 'label': None, 'url'...
# 10  [{'filename': 'auu6.txt', 'label': None, 'url'...
# 11  [{'filename': 'cuu6.txt', 'label': None, 'url'...
# 12  [{'filename': 'niu6.txt', 'label': None, 'url'...
# 13  [{'filename': 'pdu6.txt', 'label': None, 'url'...
# 14  [{'filename': 'ptu6.txt', 'label': None, 'url'...
# 15  [{'filename': 'Fe_MeyerEntel.eam', 'label': No...
# 16  [{'filename': 'Fe_2.eam', 'label': None, 'url'...
#
#                                              comments  \
# 0   Potential 1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr...
# 1   Potential 1986--Foiles-S-M--Ag--LAMMPS--ipr1 l...
# 2   Potential 1986--Foiles-S-M--Ag-Au-Cu-Ni-Pd-Pt-...
# 3   Potential 1986--Foiles-S-M--Au--LAMMPS--ipr1 l...
# 4   Potential 1986--Foiles-S-M--Cu--LAMMPS--ipr1 l...
# 5   Potential 1986--Foiles-S-M--Ni--LAMMPS--ipr1 l...
# 6   Potential 1986--Foiles-S-M--Pd--LAMMPS--ipr1 l...
# 7   Potential 1986--Foiles-S-M--Pt--LAMMPS--ipr1 l...
# 8   Potential 1989--Adams-J-B--Ag--LAMMPS--ipr1 li...
# 9   Potential 1989--Adams-J-B--Ag-Au-Cu-Ni-Pd-Pt--...
# 10  Potential 1989--Adams-J-B--Au--LAMMPS--ipr1 li...
# 11  Potential 1989--Adams-J-B--Cu--LAMMPS--ipr1 li...
# 12  Potential 1989--Adams-J-B--Ni--LAMMPS--ipr1 li...
# 13  Potential 1989--Adams-J-B--Pd--LAMMPS--ipr1 li...
# 14  Potential 1989--Adams-J-B--Pt--LAMMPS--ipr1 li...
# 15  Potential 1998--Meyer-R--Fe--LAMMPS--ipr1 list...
# 16                                                NaN
#
#                           dois
# 0   [10.1103/physrevb.32.7685]
# 1   [10.1103/physrevb.33.7983]
# 2   [10.1103/physrevb.33.7983]
# 3   [10.1103/physrevb.33.7983]
# 4   [10.1103/physrevb.33.7983]
# 5   [10.1103/physrevb.33.7983]
# 6   [10.1103/physrevb.33.7983]
# 7   [10.1103/physrevb.33.7983]
# 8      [10.1557/jmr.1989.0102]
# 9      [10.1557/jmr.1989.0102]
# 10     [10.1557/jmr.1989.0102]
# 11     [10.1557/jmr.1989.0102]
# 12     [10.1557/jmr.1989.0102]
# 13     [10.1557/jmr.1989.0102]
# 14     [10.1557/jmr.1989.0102]
# 15  [10.1103/physrevb.57.5140]
# 16                          []

# %% [markdown]
# Note that further parsing can be done with the dataframe object, similar to what was described above for the potentials entries.

# %% [markdown]
# Example of getting a single potential, with a screen prompt if multiple possible matches exist.

# %%
lmppot = potdb.get_lammps_potential(pair_style='eam', elements='Cu', pot_dir_style='working')
# Out:
# Multiple matching records retrieved from local
# 1 1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1 Cu-Ni
# 2 1986--Foiles-S-M--Ag-Au-Cu-Ni-Pd-Pt--LAMMPS--ipr1 Ag-Au-Cu-Ni-Pd-Pt
# 3 1986--Foiles-S-M--Cu--LAMMPS--ipr1 Cu
# 4 1989--Adams-J-B--Ag-Au-Cu-Ni-Pd-Pt--LAMMPS--ipr1 Ag-Au-Cu-Ni-Pd-Pt
# 5 1989--Adams-J-B--Cu--LAMMPS--ipr1 Cu
# Please select one: 1

# %% [markdown]
# ### 3.2. PotentialLAMMPS objects
#
# The returned PotentialLAMMPS objects are useful as they allow for
#
# - Identification of what models the potential contains and the necessary settings associated with them.
# - Automatic generation of the LAMMPS command lines to properly use the parameter files.
# - Downloading of any and all associated parameter files, if needed.

# %%
print(lmppot.id)
print(lmppot.potid)
print(lmppot.symbols)
print(lmppot.elements())
print(lmppot.masses())
print(lmppot.charges())
# Out:
# 1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1
# 1985--Foiles-S-M--Ni-Cu
# ['Cu', 'Ni']
# ['Cu', 'Ni']
# [63.55, 58.71]
# [0.0, 0.0]

# %% [markdown]
# The LAMMPS command lines for using the potential can then be generated using a number of methods:
#
# - pair_info() will return only the basic LAMMPS commands associated with the potential.  This is useful for previewing what commands are necessary for the potential.
# - pair_data_info() will return the LAMMPS commands associated with the potential and a data file to be loaded.
# - pair_restart_info() will return the LAMMPS commands associated with the potential and a restart file to be loaded.
#
# __Note__: it is recommended to use the methods that include system information if you plan on developing potential-agnostic methods that work with both native LAMMPS and kim model potentials.

# %%
print(lmppot.pair_info(['Cu', 'Cu', 'Ni', 'Cu']))
# Out:
# print "Potential 1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1 listed in the NIST Interatomic Potentials Repository:"
# print "https://www.ctcms.nist.gov/potentials/entry/1985--Foiles-S-M--Ni-Cu/1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1.html"
# print "Publication(s) related to the potential:"
# print "https://doi.org/10.1103/physrevb.32.7685"
# print "Parameter file(s) can be downloaded at:"
# print "https://www.ctcms.nist.gov/potentials/Download/1985--Foiles-S-M--Ni-Cu/1/Cu_smf7.eam"
# print "https://www.ctcms.nist.gov/potentials/Download/1985--Foiles-S-M--Ni-Cu/1/Ni_smf7.eam"
#
# pair_style eam
# pair_coeff 1 1 Cu_smf7.eam
# pair_coeff 2 2 Cu_smf7.eam
# pair_coeff 4 4 Cu_smf7.eam
# pair_coeff 3 3 Ni_smf7.eam
#
# mass 1 63.55
# mass 2 63.55
# mass 3 58.71
# mass 4 63.55

# %% [markdown]
# Parameter files can be retrieved and copied to the potential's pot_dir directory using either
#
# - __Database.get_lammps_potential_files()__ will copy the parameter files from the local location if they are there, or download from the listed URLs if they are not.
# - __PotentialLAMMPS.download_files()__ will download the parameter files from the listed URLs.

# %%
for artifact in lmppot.artifacts:
    print(artifact.filename)
# Out:
# Cu_smf7.eam
# Ni_smf7.eam

# %%
potdb.get_lammps_potential_files(lmppot, verbose=True)
# Out:
# Cu_smf7.eam already in .
# Ni_smf7.eam already in .

# %%
for artifact in lmppot.artifacts:
    print(Path(artifact.filename).is_file())
# Out:
# True
# True

# %% [markdown]
# ### 3.3. OpenKIM models
#
# OpenKIM models can be listed alongside the native LAMMPS potentials from NIST as well, although it requires a little bit extra setup. The included OpenKIM listings are built based on the models you have available rather than the full list of known models. The available OpenKIM models can be specified in one of three ways when initializing a Database object or calling get_lammps_potential(s):
#
# - __kim_api_directory__ is the path to the directory containing the specific kim-api-collections-management executable you wish to use. If provided, then the list of installed KIM models will be automatically queried.
# - __kim_models__ is a list of the full kim ids of the models to include.  This allows for the list of installed KIM models to be changed on the fly.
# - __kim_models_file__ is the path to a file containing a whitespace-delimited list of full kim ids to include.  This allows for a stored list of installed KIM models to be accessed, which is useful if the kim-api-collections-management is not accessible on your current machine or if you plan on using multiple kim-api environments when running simulations.
#
# Note that a default kim_api_directory or a default list of kim_models can be saved using the potentials.settings.  Here, default values have already been set, meaning that it is building listings based on that.

# %% [markdown]
# Get LAMMPS potentials and KIM models containing element Ru.

# %%
lmppots, lmppots_df = potdb.get_lammps_potentials(elements='Ru', return_df=True, verbose=True)
lmppots_df
# Out:
# Found 1 matching potential_LAMMPS records in local library
# Found 1 matching potential_LAMMPS records in remote library
#  - 0 remote records are new
# Found 2 matching potential_LAMMPS_KIM records in local library
# Remote access failed: 'PotentialLAMMPSKIM' object has no attribute '_PotentialLAMMPSKIM__potid'
# Found 0 matching potential_LAMMPS_KIM records in remote library
# Built 3 lammps potentials for KIM models
#                                 name  \
# 0  2008--Fortini-A--Ru--LAMMPS--ipr1
# 1                    MO_114077951467
# 2                    MO_959249795837
# 3                    MO_959249795837
#
#                                                   id  \
# 0                  2008--Fortini-A--Ru--LAMMPS--ipr1
# 1  EAM_Dynamo_FortiniMendelevBuldyrev_2008_Ru__MO...
# 2  LJ_ElliottAkerson_2015_Universal__MO_959249795...
# 3  LennardJones612_UniversalShifted__MO_959249795...
#
#                                     key  \
# 0  90e928ab-acad-4e31-8f26-f13d5fb37b53
# 1  7ae2c11d-cb15-4b40-8c85-6b92cbb43f50
# 2  da76eb36-7ca1-421a-bd64-8f6bdd905b15
# 3  da76eb36-7ca1-421a-bd64-8f6bdd905b15
#
#                                                  url  \
# 0               90e928ab-acad-4e31-8f26-f13d5fb37b53
# 1  https://potentials.nist.gov/pid/rest/local/pot...
# 2  https://potentials.nist.gov/pid/rest/local/pot...
# 3  https://potentials.nist.gov/pid/rest/local/pot...
#
#                                                potid  \
# 0  2008--Fortini-A-Mendelev-M-I-Buldyrev-S-Srolov...
# 1  2008--Fortini-A-Mendelev-M-I-Buldyrev-S-Srolov...
# 2                    2015--Elliott-R-S-Akerson-A--Ru
# 3                    2015--Elliott-R-S-Akerson-A--Ru
#
#                                  potkey  \
# 0  8a94f366-a892-461e-9d3d-e30a76276727
# 1  8a94f366-a892-461e-9d3d-e30a76276727
# 2  b3ce924c-9c31-428a-bcb3-c104e459b8f7
# 3  b3ce924c-9c31-428a-bcb3-c104e459b8f7
#
#                                               poturl  units atom_style  \
# 0                                                NaN  metal     atomic
# 1  https://potentials.nist.gov/pid/rest/local/pot...  metal        NaN
# 2  https://potentials.nist.gov/pid/rest/local/pot...  metal        NaN
# 3  https://potentials.nist.gov/pid/rest/local/pot...  metal        NaN
#
#    allsymbols pair_style  status symbols elements  \
# 0         0.0     eam/fs  active    [Ru]     [Ru]
# 1         NaN        kim    None    [Ru]     [Ru]
# 2         NaN        kim    None    [Ru]     [Ru]
# 3         NaN        kim    None    [Ru]     [Ru]
#
#                                            artifacts  \
# 0  [{'filename': 'Ru.eam.fs', 'label': None, 'url...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#                                             comments                 dois  \
# 0  Potential 2008--Fortini-A--Ru--LAMMPS--ipr1 li...  [10.1063/1.2991301]
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
#
#          shortcode                                         fullkimids
# 0              NaN                                                NaN
# 1  MO_114077951467  [EAM_Dynamo_Fortini_Mendelev_Ru__MO_1140779514...
# 2  MO_959249795837  [LennardJones612_UniversalShifted__MO_95924979...
# 3  MO_959249795837  [LennardJones612_UniversalShifted__MO_95924979...

# %% [markdown]
# The returned PotentialLAMMPSKIM objects have most of the same attributes as the PotentialLAMMPS objects, except there are no files to download.

# %%
print(lmppots[1].id)
print(lmppots[1].potid)
print(lmppots[1].symbols)
print(lmppots[1].elements())
print(lmppots[1].masses())
print(lmppots[1].charges())
# Out:
# EAM_Dynamo_FortiniMendelevBuldyrev_2008_Ru__MO_114077951467_005
# 2008--Fortini-A-Mendelev-M-I-Buldyrev-S-Srolovitz-D--Ru
# ['Ru']
# ['Ru']
# [101.07]
# [0.0]

# %%
print(lmppots[1].pair_info())
# Out:
# kim_init EAM_Dynamo_FortiniMendelevBuldyrev_2008_Ru__MO_114077951467_005 metal
# kim_interactions Ru
# mass 1 101.07
