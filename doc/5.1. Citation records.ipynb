# %% [markdown]
# # Citation records
#
# Citation records describe a single citation associated with a potential.  This citation can either be a published citation with full bibliographic information, or an unpublished citation giving a potential a creation year and primary author.

# %%
# https://github.com/lmhale99/potentials
import potentials

print('Notebook tested for potentials version', potentials.__version__)
# Out:
# Notebook tested for potentials version 0.4.0

# %%
potdb = potentials.Database(local=True, remote=True)

# %% [markdown]
# ## 1. Database methods
#
# ### 1.1. fetch_citation()
#
# The Database.fetch_citation() method will return a single citation based on a given DOI.  It will first check the local and remote databases to see if a matching record already exists.  If a citation with that DOI is not found, the information will be downloaded from CrossRef.  Unpublished records in the local/remote databases can be retrieved by specifying the record name rather than the DOI.
#
# - __doi__ (*str*) The citation's DOI.  If the citation has no DOI, then the citation's record name should be given instead.
# - __local__ (*bool, optional*) Indicates if the local location is to be searched.  Default value matches the value set when the database was initialized.
# - __remote__ (*bool, optional*) Indicates if the remote location is to be searched.  Default value matches the value set when the database was initialized.
# - __verbose__ (*bool, optional*) If True, info messages will be printed during operations.  Default value is False.

# %% [markdown]
# Fetch dummy citation from CrossRef

# %%
citation = potdb.fetch_citation('10.5555/12345678', verbose=True)
# Out:
# Citation retrieved from CrossRef

# %% [markdown]
# ### 1.2. get_citations(), get_citation(), download_citations()
#
# These methods build upon the Database's corresponding generic record methods with style='Citation' by defining the specific kwargs query parameters associated with the Citation record style.
# See the [4. Database class](4. Database class.ipynb) Notebook for details on the generic record methods.
#
# Query parameters
#
# - __name__ (*str or list, optional*) The name(s) of records to limit the search by.
# - __year__ (*int or list, optional*) Publication year(s) to limit the search by.
# - __volume__ (*int or list, optional*) Journal volume(s) to limit the search by.
# - __title__ (*str or list, optional*) Word(s) to search for in the article titles.
# - __journal__ (*str or list, optional*) Journal name(s) to limit the search by.
# - __doi__ (*str or list, optional*) Article DOI(s) to limit the search by.
# - __author__ (*str or list, optional*) Author name(s) to search for.  Works best for last names only.
# - __abstract__ (*str or list, optional*) Word(s) to search for in the article abstracts.

# %% [markdown]
# Query all citations with author Mishin.

# %%
citations, citations_df = potdb.get_citations(verbose=True, return_df=True, author='Mishin')
# Out:
# Found 21 matching Citation records in local library
# 100%|███████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 22.98it/s]
# Found 21 matching Citation records in remote library
#  - 0 remote records are new

# %% [markdown]
# With return_df=True, a pandas DataFrame containing the metadata fields of the matching records is also returned.  This can be used for a quick overview of the returned records and to further parse the results.

# %%
citations_df
# Out:
#                                  name  doctype  \
# 0       10.1016_j.actamat.2003.11.026  journal
# 1       10.1016_j.actamat.2005.05.001  journal
# 2       10.1016_j.actamat.2015.08.052  journal
# 3       10.1016_j.actamat.2021.116980  journal
# 4     10.1016_j.commatsci.2021.111180  journal
# 5          10.1016_j.susc.2006.02.010  journal
# 6          10.1038_s41467-019-10343-5  journal
# 7           10.1080_14786430903258184  journal
# 8          10.1088_0965-0393_14_5_002  journal
# 9       10.1088_0965-0393_23_6_065006  journal
# 10           10.1088_1361-651x_aae400  journal
# 11           10.1103_physrevb.59.3393  journal
# 12         10.1103_physrevb.63.224106  journal
# 13         10.1103_physrevb.65.224114  journal
# 14         10.1103_physrevb.68.024102  journal
# 15         10.1103_physrevb.77.094131  journal
# 16         10.1103_physrevb.82.144115  journal
# 17         10.1103_physrevb.83.054116  journal
# 18         10.1103_physrevb.86.134116  journal
# 19         10.1103_physrevb.95.224103  journal
# 20  10.1103_physrevmaterials.4.113807  journal
#
#                                                 title  \
# 0   Atomistic modeling of the γ and γ'-phases of t...
# 1   Phase stability in the Fe-Ni system: Investiga...
# 2   Angular-dependent interatomic potential for th...
# 3   Machine-learning interatomic potentials for ma...
# 4   Development of a physically-informed neural ne...
# 5   Embedded-atom potential for Fe and its applica...
# 6   Physically~informed artificial neural networks...
# 7   Development of an interatomic potential for th...
# 8     An embedded-atom potential for the Cu-Ag system
# 9   Interatomic potential for the ternary Ni–Al–Co...
# 10  Angular-dependent interatomic potential for th...
# 11  Interatomic potentials for monoatomic metals f...
# 12  Structural stability and lattice defects in co...
# 13                Embedded-atom potential for B2-NiAl
# 14  Interatomic potentials for atomistic simulatio...
# 15  Interatomic potential for the Cu-Ta system and...
# 16  Angular-dependent interatomic potential for th...
# 17         Interatomic potential for the Al-Cu system
# 18     Embedded-atom potential for hcp and fcc cobalt
# 19  Optimized interatomic potential for silicon an...
# 20  Development of a general-purpose machine-learn...
#
#                                                author  \
# 0   [{'givenname': 'Y.', 'surname': 'Mishin', 'suf...
# 1   [{'givenname': 'Y.', 'surname': 'Mishin', 'suf...
# 2   [{'givenname': 'G.P.', 'surname': 'Purja Pun',...
# 3   [{'givenname': 'Y.', 'surname': 'Mishin', 'suf...
# 4   [{'givenname': 'Y.-S.', 'surname': 'Lin', 'suf...
# 5   [{'givenname': 'H.', 'surname': 'Chamati', 'su...
# 6   [{'givenname': 'G.P.', 'surname': 'Purja Pun',...
# 7   [{'givenname': 'G.P.', 'surname': 'Purja Pun',...
# 8   [{'givenname': 'P.L.', 'surname': 'Williams', ...
# 9   [{'givenname': 'G.P.', 'surname': 'Purja Pun',...
# 10  [{'givenname': 'C.A.', 'surname': 'Howells', '...
# 11  [{'givenname': 'Y.', 'surname': 'Mishin', 'suf...
# 12  [{'givenname': 'Y.', 'surname': 'Mishin', 'suf...
# 13  [{'givenname': 'Y.', 'surname': 'Mishin', 'suf...
# 14  [{'givenname': 'R.R.', 'surname': 'Zope', 'suf...
# 15  [{'givenname': 'A.', 'surname': 'Hashibon', 's...
# 16  [{'givenname': 'F.', 'surname': 'Apostol', 'su...
# 17  [{'givenname': 'F.', 'surname': 'Apostol', 'su...
# 18  [{'givenname': 'G.P.', 'surname': 'Purja Pun',...
# 19  [{'givenname': 'G.P.', 'surname': 'Purja Pun',...
# 20  [{'givenname': 'G.P.', 'surname': 'Purja Pun',...
#
#                                           publication    year month volume  \
# 0                                     Acta Materialia  2004.0   NaN     52
# 1                                     Acta Materialia  2005.0   NaN     53
# 2                                     Acta Materialia  2015.0   NaN    100
# 3                                     Acta Materialia  2021.0   NaN    214
# 4                     Computational Materials Science  2022.0   NaN    205
# 5                                     Surface Science  2006.0   NaN    600
# 6                               Nature Communications  2019.0   NaN     10
# 7                              Philosophical Magazine  2009.0   NaN     89
# 8   Modelling and Simulation in Materials Science ...  2006.0   NaN     14
# 9   Modelling and Simulation in Materials Science ...  2015.0   NaN     23
# 10  Modelling and Simulation in Materials Science ...  2018.0   NaN     26
# 11                                  Physical Review B  1999.0   NaN     59
# 12                                  Physical Review B  2001.0   NaN     63
# 13                                  Physical Review B  2002.0   NaN     65
# 14                                  Physical Review B  2003.0   NaN     68
# 15                                  Physical Review B  2008.0   NaN     77
# 16                                  Physical Review B  2010.0   NaN     82
# 17                                  Physical Review B  2011.0   NaN     83
# 18                                  Physical Review B  2012.0   NaN     86
# 19                                  Physical Review B  2017.0   NaN     95
# 20                          Physical Review Materials  2020.0   NaN      4
#
#     issue                                           abstract      pages  \
# 0       6  A new embedded-atom potential has been develop...  1451-1467
# 1      15  First-principles calculations of the energy of...  4029-4041
# 2     NaN  Atomistic computer simulations are capable of ...    377-391
# 3     NaN  Large-scale atomistic computer simulations of ...     116980
# 4     NaN  Large-scale atomistic simulations of materials...     111180
# 5       9  We have constructed an embedded-atom potential...  1793-1803
# 6       1  Large-scale atomistic computer simulations of ...       2339
# 7   34-36  We construct an interatomic potential for the ...  3245-3267
# 8       5  A new embedded-atom method (EAM) potential has...    817-833
# 9       6  Ni–Al–Co is a promising system for ferromagnet...     065006
# 10      8  A new interatomic potential has been developed...     085008
# 11      5  We demonstrate an approach to the development ...  3393-3407
# 12     22  We evaluate the ability of the embedded-atom m...     224106
# 13     22  An embedded-atom potential has been constructe...     224114
# 14      2  Semiempirical interatomic potentials have been...     024102
# 15      9  An angle-dependent interatomic potential has b...     094131
# 16     14  We report on the development of an angular-dep...     144115
# 17      5  An angular-dependent interatomic potential has...     054116
# 18     13  We report on the development of an embedded-at...     134116
# 19     22  An optimized interatomic potential has been co...     224103
# 20     11  Interatomic potentials constitute the key comp...     113807
#
#                                   doi  url  \
# 0       10.1016/j.actamat.2003.11.026  NaN
# 1       10.1016/j.actamat.2005.05.001  NaN
# 2       10.1016/j.actamat.2015.08.052  NaN
# 3       10.1016/j.actamat.2021.116980  NaN
# 4     10.1016/j.commatsci.2021.111180  NaN
# 5          10.1016/j.susc.2006.02.010  NaN
# 6          10.1038/s41467-019-10343-5  NaN
# 7           10.1080/14786430903258184  NaN
# 8          10.1088/0965-0393/14/5/002  NaN
# 9       10.1088/0965-0393/23/6/065006  NaN
# 10           10.1088/1361-651x/aae400  NaN
# 11           10.1103/physrevb.59.3393  NaN
# 12         10.1103/physrevb.63.224106  NaN
# 13         10.1103/physrevb.65.224114  NaN
# 14         10.1103/physrevb.68.024102  NaN
# 15         10.1103/physrevb.77.094131  NaN
# 16         10.1103/physrevb.82.144115  NaN
# 17         10.1103/physrevb.83.054116  NaN
# 18         10.1103/physrevb.86.134116  NaN
# 19         10.1103/physrevb.95.224103  NaN
# 20  10.1103/physrevmaterials.4.113807  NaN
#
#                                                bibtex  \
# 0   @article{Mishin_2004,\n abstract = {A new embe...
# 1   @article{Mishin_2005,\n abstract = {First-prin...
# 2   @article{Purja_Pun_2015,\n abstract = {Atomist...
# 3   @article{Mishin_2021,\n abstract = {Large-scal...
# 4   @article{Lin_2022,\n abstract = {Large-scale a...
# 5   @article{Chamati_2006,\n abstract = {We have c...
# 6   @article{Pun_2019,\n abstract = {Large-scale a...
# 7   @article{Purja_Pun_2009,\n abstract = {We cons...
# 8   @article{Williams_2006,\n abstract = {A new em...
# 9   @article{Purja_Pun_2015,\n abstract = {Ni–Al–C...
# 10  @article{Howells_2018,\n abstract = {A new int...
# 11  @article{Mishin_1999,\n abstract = {We demonst...
# 12  @article{Mishin_2001,\n abstract = {We evaluat...
# 13  @article{Mishin_2002,\n abstract = {An embedde...
# 14  @article{Zope_2003,\n abstract = {Semiempirica...
# 15  @article{Hashibon_2008,\n abstract = {An angle...
# 16  @article{Apostol_2010,\n abstract = {We report...
# 17  @article{Apostol_2011,\n abstract = {An angula...
# 18  @article{Pun_2012,\n abstract = {We report on ...
# 19  @article{Pun_2017,\n abstract = {An optimized ...
# 20  @article{Pun_2020,\n abstract = {Interatomic p...
#
#                                          year_authors
# 0                                      2004--Mishin-Y
# 1     2005--Mishin-Y-Mehl-M-J-Papaconstantopoulos-D-A
# 2   2015--Purja-Pun-G-P-Darling-K-A-Kecskes-L-J-Mi...
# 3                                      2021--Mishin-Y
# 4                2022--Lin-Y-S-Purja-Pun-G-P-Mishin-Y
# 5   2006--Chamati-H-Papanicolaou-N-I-Mishin-Y-Papa...
# 6    2019--Purja-Pun-G-P-Batra-R-Ramprasad-R-Mishin-Y
# 7                        2009--Purja-Pun-G-P-Mishin-Y
# 8            2006--Williams-P-L-Mishin-Y-Hamilton-J-C
# 9              2015--Purja-Pun-G-P-Yamakov-V-Mishin-Y
# 10                         2018--Howells-C-A-Mishin-Y
# 11  1999--Mishin-Y-Farkas-D-Mehl-M-J-Papaconstanto...
# 12  2001--Mishin-Y-Mehl-M-J-Papaconstantopoulos-D-...
# 13    2002--Mishin-Y-Mehl-M-J-Papaconstantopoulos-D-A
# 14                            2003--Zope-R-R-Mishin-Y
# 15        2008--Hashibon-A-Lozovoi-A-Y-Mishin-Y-et-al
# 16                           2010--Apostol-F-Mishin-Y
# 17                           2011--Apostol-F-Mishin-Y
# 18                       2012--Purja-Pun-G-P-Mishin-Y
# 19                       2017--Purja-Pun-G-P-Mishin-Y
# 20      2020--Purja-Pun-G-P-Yamakov-V-Hickman-J-et-al

# %% [markdown]
# ### 1.3. save_citation(), upload_citation(), delete_citation()
#
# These methods are identical to calling the Database's corresponding generic record methods with style='Citation'.  See the [4. Database class](4. Database class.ipynb) Notebook for details on the generic record methods.

# %% [markdown]
# ## 2. Citation class
#
# The Citation class is primarily designed to interact with bibtex formatted citations.
#
# See [5. Record Classes](5. Record Classes.ipynb) for details on the common methods and attributes that Citation shares with the other Record subclasses.

# %% [markdown]
# ### 2.1. Python representation
#
# Style-specific methods and attributes:
#
# - __year_authors__ (*str*) Returns an id of YEAR--LAST-F-M with up to 4 authors.  The ids/names of Potential records are built upon this value from their primary citations.
# - __year_first_author__ (*str*) Returns an id of YEAR--LAST-F-M for only the first author.  The ids/names of potential_LAMMPS records are built upon this value from their primary citations.
# - __bibdict__ (*dict*) A dictionary representing bibtex fields.  The terms can be modified or added to.
# - __bibtex__ (*str*) The formatted bibtex content
# - __build_bibtex()__ Builds the bibtex string from the values in the bibdict.
# - __parse_authors()__ A utility function for parsing the bibtex author field to separate out author names.
# - __set_values(name=None, \*\*kwargs)__ Allows for the values of multiple attributes to be set at the same time.  Any kwargs given here are set to bib.

# %%
print('citation.style:            ', citation.style)
print('citation.name:             ', citation.name)
print('citation.year_authors:     ', citation.year_authors)
print('citation.year_first_author:', citation.year_first_author)
# Out:
# citation.style:             Citation
# citation.name:              10.5555_12345678
# citation.year_authors:      2008--Carberry-J
# citation.year_first_author: 2008--Carberry-J

# %%
citation.bibdict
# Out:
# {'ID': '2008--Carberry-J',
#  'ENTRYTYPE': 'article',
#  'author': 'Carberry, J.',
#  'title': 'Toward a Unified Theory of High-Energy Metaphysics: Silly String Theory',
#  'journal': 'Journal of Psychoceramics',
#  'year': '2008',
#  'volume': '5',
#  'number': '11',
#  'pages': '1–3',
#  'month': 'August',
#  'doi': '10.5555/12345678'}

# %%
citation.build_bibtex()
print(citation.bibtex)
# Out:
# @article{2008--Carberry-J,
#  author = {Carberry, J.},
#  doi = {10.5555/12345678},
#  journal = {Journal of Psychoceramics},
#  month = {August},
#  number = {11},
#  pages = {1–3},
#  title = {Toward a Unified Theory of High-Energy Metaphysics: Silly String Theory},
#  volume = {5},
#  year = {2008}
# }

# %% [markdown]
# ### 2.2. Data Model representation
#
# Style-specific notes:
#
# - __Caution__: The data model for Citations contains both metadata fields for the citation as well as a field containing the full associated bibtex-formatted string.  When load_model() and reload_model() are called, only the bibtex field is loaded *not* the metadata fields. For this reason, bib should primarily be used to update the fields rather than trying to update them using model.
# - The kwargs that mongoquery and cdcsquery support are the same as the query kwargs listed above for the database methods.

# %%
citation.html(render=True)
# Out:
# <div><div class="citation"><b>Citation: </b>J. Carberry (2008), "Toward a Unified Theory of High-Energy Metaphysics: Silly String Theory", <i>Journal of Psychoceramics</i>, <b>5(11)</b>, 1&#8211;3. DOI: <a href="https://doi.org/10.5555/12345678" class="external">10.5555/12345678</a>.<br/></div></div>

# %%
print(citation.model.json(indent=4))
# Out:
# {
#     "citation": {
#         "document-type": "journal",
#         "title": "Toward a Unified Theory of High-Energy Metaphysics: Silly String Theory",
#         "author": {
#             "given-name": "J.",
#             "surname": "Carberry"
#         },
#         "publication-name": "Journal of Psychoceramics",
#         "publication-date": {
#             "year": 2008,
#             "month": "--08"
#         },
#         "volume": "5",
#         "issue": "11",
#         "pages": "1\u20133",
#         "DOI": "10.5555/12345678",
#         "bibtex": "@article{2008--Carberry-J,\n author = {Carberry, J.},\n doi = {10.5555/12345678},\n journal = {Journal of Psychoceramics},\n month = {August},\n number = {11},\n pages = {1\u20133},\n title = {Toward a Unified Theory of High-Energy Metaphysics: Silly String Theory},\n volume = {5},\n year = {2008}\n}\n"
#     }
# }

# %% [markdown]
# ### 2.3. Metadata representation
#
# Style-specific notes:
#
# - The kwargs that pandasfilter supports are the same as the query kwargs listed above for the database methods.
# - metadata returns a dictionary with name, year_authors, and the fields in bib.

# %%
citation.metadata()
# Out:
# {'name': '10.5555_12345678',
#  'doctype': 'journal',
#  'title': 'Toward a Unified Theory of High-Energy Metaphysics: Silly String Theory',
#  'author': [{'givenname': 'J.', 'surname': 'Carberry', 'suffix': None}],
#  'publication': 'Journal of Psychoceramics',
#  'year': 2008,
#  'month': 8,
#  'volume': '5',
#  'issue': '11',
#  'abstract': None,
#  'pages': '1–3',
#  'doi': '10.5555/12345678',
#  'url': None,
#  'bibtex': '@article{2008--Carberry-J,\n author = {Carberry, J.},\n doi = {10.5555/12345678},\n journal = {Journal of Psychoceramics},\n month = {August},\n number = {11},\n pages = {1–3},\n title = {Toward a Unified Theory of High-Energy Metaphysics: Silly String Theory},\n volume = {5},\n year = {2008}\n}\n',
#  'year_authors': '2008--Carberry-J'}
