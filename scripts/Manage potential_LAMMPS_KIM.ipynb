# %%
from DataModelDict import DataModelDict as DM
from pathlib import Path

import uuid

import potentials

import requests

# %%
machine = 'laptop'
#machine = 'desktop'

# %%
# Set passwordfile based on machine
if machine == 'laptop':
    passwordfile = Path('C:/Users/lmh1/Documents/potentials_nist_gov/password.txt')
elif machine == 'desktop':
    passwordfile = Path('E:/potentials_nist_gov/password.txt')
else:
    raise ValueError(f'passwordfile not set for machine {machine}')

# Load database using username + password
with open(Path(passwordfile)) as f:
    username, password = f.read().strip().split()
db = potentials.Database(username=username, password=password)

# %%
db.load_potentials(remote=False, verbose=True)
db.set_installed_kim_models([])
db.load_lammps_potentials(remote=False, verbose=True)
# Out:
# Loaded 640 local potentials
# Loaded 397 local LAMMPS potentials
# Building lammps potentials for kim models
# No installed kim models identified

# %%
def get_fullkimids():
    """Scrapes the openKIM website for the list of all current KIM models"""
    r = requests.get('https://openkim.org/browse/models/alphabetical')
    fullids = []
    s = 0
    e = 0
    while True:
        try:
            s = r.text[e:].index('<a href="/id/') + 13 + e
            e = r.text[s:].index('">') + s
            fullids.append(r.text[s:e])            
        except:
            break
    
    return fullids

def previouskimid(fullkimid):
    """Scrapes the openKIM website to find the previous version of a kim model"""
    r = requests.get(f'https://openkim.org/id/{fullkimid}')
    s = r.text.index('<span class=title>Previous Version</span>')
    s = r.text[s:].index('<a href="/id/') + s + 13
    e = r.text[s:].index('">') + s
    return r.text[s:e]

def getshortcode(fullkimid):
    """Extracts the kim shortcode from the fullkimid"""
    return '_'.join(fullkimid.split('_')[-3:-1])

def sortfxn(kimid):
    return int(kimid.split('_')[-1])

def build_kim_record(potdb, fullkimid):
    
    shortcode = getshortcode(fullkimid)
    comment = ''
    
    # Load existing record
    fname = Path(potdb.localpath, 'potential_LAMMPS_KIM', f'{shortcode}.json')
    if fname.is_file():
        model = DM(fname)

    # Initialize new record
    else:
        comment += ' - is new\n'
        model = DM()
        model['potential-LAMMPS-KIM'] = DM()
        model['potential-LAMMPS-KIM']['key'] = None
        model['potential-LAMMPS-KIM']['id'] = shortcode

    # Add associated potential information if missing
    comment += addpotinfo(potdb, model)        

    # Get previous versions
    allids = [fullkimid]
    version = fullkimid.split('_')[-1]
    while version != '000':
        allids.append(previouskimid(allids[-1]))
        version = allids[-1].split('_')[-1]
    allids = sorted(allids, key=sortfxn)

    saveids = model['potential-LAMMPS-KIM'].aslist('full-kim-id')
    count = 0
    for fid in allids:
        if fid not in saveids:
            model['potential-LAMMPS-KIM'].append('full-kim-id', fid)
            count += 1
    if count > 0:
        comment += f' - {count} versions added\n'

    # Reorder
    model['potential-LAMMPS-KIM']['key'] = model['potential-LAMMPS-KIM'].pop('key')
    model['potential-LAMMPS-KIM']['id'] = model['potential-LAMMPS-KIM'].pop('id')
    if 'potential' in model['potential-LAMMPS-KIM']:
        model['potential-LAMMPS-KIM']['potential'] = model['potential-LAMMPS-KIM'].pop('potential')
    model['potential-LAMMPS-KIM']['full-kim-id'] = model['potential-LAMMPS-KIM'].pop('full-kim-id')

    if comment != '':
        print(shortcode)
        print(comment)
    
    #with open(fname, 'w') as f:
    #    model.json(fp=f, indent=4)

def addpotinfo(potdb, model):
    
    shortcode = model['potential-LAMMPS-KIM']['id']
    comment = ''
    
    for potential in potdb.potentials:
        match = False
        for implementation in potential.implementations:
            if implementation.id == shortcode:
                match = True
                break
        
        if match:
            
            # Set/check key
            if model['potential-LAMMPS-KIM']['key'] is None:
                model['potential-LAMMPS-KIM']['key'] = implementation.key
            elif model['potential-LAMMPS-KIM']['key'] != implementation.key:
                comment += f' - key mismatch with {potential.id} {implementation.id}\n' 
            
            # Search for existing potential listing
            newpot = True
            for potinfo in model['potential-LAMMPS-KIM'].aslist('potential'):
                if potinfo['key'] == potential.key:
                    newpot = False
                    break
            
            if newpot:            
                # Build potential info
                potinfo = DM()
                model['potential-LAMMPS-KIM'].append('potential', potinfo)
                potinfo['key'] = potential.key
                potinfo['id'] = potential.id
                comment += ' - new potential info added\n'
            
            # Add atom info
            if 'atom' not in potinfo:
                noatom = True
                for implementation in potential.implementations:
                    try:
                        sibling = potdb.get_lammps_potential(id = implementation.id)
                    except:
                        pass
                    else:
                        potinfo['atom'] = sibling['potential-LAMMPS']['atom']
                        noatom = False
                        break
            
                if noatom:
                    count = 0
                    for element in potential.elements:
                        potinfo.append('atom', DM([('element', element)]))
                        count += 0
                    if count > 0:
                        comment += f' - {count} new atoms added\n'
                    if 'atom' not in potinfo:
                        comment += f' - has no atom info for {potential.id}\n'
    
    # Check if potential is in model after function
    if 'potential' not in model['potential-LAMMPS-KIM']:
        comment += ' - has no matching potential\n'

    return comment

def update_kim_models(potdb):
    fullkimids = get_fullkimids()
    
    for fullkimid in fullkimids:
        
        # Skip non-native KIM models (for now)
        if '__MO_' not in fullkimid:
            continue
        
        build_kim_record(potdb, fullkimid)

# %%
update_kim_models(db)
# Out:
# MO_546673549085
#  - has no matching potential
#
# MO_848899341753
#  - has no matching potential
#
# MO_463728687265
#  - has no matching potential
#
# MO_028979335952
#  - has no matching potential
#
# MO_135739722270
#  - has no matching potential
#
# MO_958395190627
#  - has no matching potential
#
# MO_390178379548
#  - has no matching potential
#
# MO_492310898779
#  - has no matching potential
#
# MO_700541006254
#  - has no matching potential
#
# MO_427873955970
#  - has no matching potential
#
# MO_115454747503
#  - has no matching potential
#
# MO_410167849923
#  - has no matching potential
#
# MO_179158257180
#  - has no matching potential
#
# MO_808662295149
#  - has no matching potential
#
# MO_671124822359
#  - has no matching potential
#
# MO_348689608050
#  - has no matching potential
#
# MO_131642768288
#  - has no matching potential
#
# MO_557492625287
#  - has no matching potential
#
# MO_093637366498
#  - is new
#  - has no matching potential
#  - 1 versions added
#
# MO_099716416216
#  - has no matching potential
#
# MO_815057898706
#  - has no matching potential
#
# MO_883726743759
#  - has no matching potential
#
# MO_227887284491
#  - has no matching potential
#
# MO_549900287421
#  - has no matching potential
#
# MO_937008984446
#  - has no matching potential
#
# MO_162736908871
#  - has no matching potential
#
# MO_399431830125
#  - has no matching potential
#
# MO_112077942578
#  - has no matching potential
#
# MO_520569947398
#  - has no matching potential
#
# MO_050147023220
#  - has no matching potential
#
# MO_893505888031
#  - has no matching potential
#
# MO_474962707676
#  - has no matching potential
#
# MO_708495328010
#  - has no matching potential
#
# MO_262519520678
#  - has no matching potential
#
# MO_068985622065
#  - has no matching potential
#
# MO_716623333967
#  - has no matching potential
#
# MO_616482358807
#  - has no matching potential
#
# MO_101997554790
#  - has no matching potential
#
# MO_353393547686
#  - has no matching potential
#
# MO_924736622203
#  - has no matching potential
#
# MO_356501945107
#  - has no matching potential
#
# MO_008996216289
#  - has no matching potential
#
# MO_086900950763
#  - has no matching potential
#
# MO_477506997611
#  - has no matching potential
#
# MO_813575892799
#  - has no matching potential
#
# MO_050461957184
#  - has no matching potential
#
# MO_611309973581
#  - has no matching potential
#
# MO_935641703527
#  - has no matching potential
#
# MO_018428823000
#  - has no matching potential
#
# MO_110119204723
#  - has no matching potential
#
# MO_072689718616
#  - has no matching potential
#
# MO_427397414195
#  - has no matching potential
#
# MO_876687166519
#  - has no matching potential
#
# MO_618133763375
#  - has no matching potential
#
# MO_478967255435
#  - has no matching potential
#
# MO_058537087384
#  - has no matching potential
#
# MO_321355778754
#  - has no matching potential
#
# MO_329881861557
#  - has no matching potential
#
# MO_343168101490
#  - has no matching potential
#
# MO_134206624109
#  - has no matching potential
#
# MO_070542625990
#  - has no matching potential
#
# MO_059320827436
#  - has no matching potential
#
# MO_325675357262
#  - has no matching potential
#
# MO_793141037706
#  - has no matching potential
#
# MO_545073984441
#  - has no matching potential
#
# MO_070797404269
#  - has no matching potential
#
# MO_831380044253
#  - has no matching potential
#
# MO_020840179467
#  - has no matching potential
#
# MO_280985530673
#  - has no matching potential
#
# MO_912978207512
#  - has no matching potential
#
# MO_058735400462
#  - has no matching potential
#
# MO_663355627503
#  - has no matching potential
#
# MO_179420363944
#  - has no matching potential
#
# MO_129364204512
#  - has no matching potential
#
# MO_046547823135
#  - has no matching potential
#
# MO_127847080751
#  - has no matching potential
#
# MO_091278480940
#  - has no matching potential
#
# MO_856956178669
#  - has no matching potential
#
# MO_095610951957
#  - has no matching potential
#
# MO_332211522050
#  - has no matching potential
#
# MO_946208788356
#  - has no matching potential
#
# MO_432861766738
#  - has no matching potential
#
# MO_409065472403
#  - has no matching potential
#
# MO_063626065437
#  - has no matching potential
#
# MO_999198119251
#  - has no matching potential
#
# MO_533426548156
#  - has no matching potential
#
# MO_075279800195
#  - has no matching potential
#
# MO_744610363128
#  - has no matching potential
#
# MO_122936827583
#  - has no matching potential
#
# MO_354152387712
#  - has no matching potential
#
# MO_862371677648
#  - has no matching potential
#
# MO_771146361182
#  - has no matching potential
#
# MO_269937397263
#  - has no matching potential
#
# MO_105449194206
#  - has no matching potential
#
# MO_560940542741
#  - has no matching potential
#
# MO_315820974149
#  - has no matching potential
#
# MO_596300673917
#  - has no matching potential
#
# MO_260546967793
#  - has no matching potential
#
# MO_162036141261
#  - has no matching potential
#
# MO_344724145339
#  - has no matching potential
#
# MO_612225165948
#  - has no matching potential
#
# MO_072444764353
#  - has no matching potential
#
# MO_500937681860
#  - has no matching potential
#
# MO_022920256108
#  - has no matching potential
#
# MO_316045643888
#  - has no matching potential
#
# MO_313717476091
#  - has no matching potential
#
# MO_444394830472
#  - has no matching potential
#
# MO_430846853065
#  - has no matching potential
#
# MO_694335101831
#  - has no matching potential
#
# MO_849011491644
#  - has no matching potential
#
# MO_380272712420
#  - has no matching potential
#
# MO_486450342170
#  - has no matching potential
#
# MO_344044439515
#  - has no matching potential
#
# MO_880803040302
#  - has no matching potential
#
# MO_912636107108
#  - has no matching potential
#
# MO_321233176498
#  - has no matching potential
#
# MO_360068930164
#  - has no matching potential
#
# MO_612732924171
#  - has no matching potential

# %%
model.finds('atom')
# Out:
# [DataModelDict([('element', 'Al')]),
#  DataModelDict([('element', 'Ag')]),
#  DataModelDict([('element', 'Au')]),
#  DataModelDict([('element', 'Cu')]),
#  DataModelDict([('element', 'Ni')]),
#  DataModelDict([('element', 'Pd')]),
#  DataModelDict([('element', 'Pt')])]

# %%
def addpotinfo(potdb, model):
    
    shortcode = model['potential-LAMMPS-KIM']['id']
    
    for potential in potdb.potentials:
        match = False
        for implementation in potential.implementations:
            if implementation.id == shortcode:
                match = True
                break
        
        if match:
            
            # Set/check key
            if model['potential-LAMMPS-KIM']['key'] is None:
                model['potential-LAMMPS-KIM']['key'] = implementation.key
            elif model['potential-LAMMPS-KIM']['key'] != implementation.key:
                print(shortcode, 'key mismatch with', potential.id, implementation.id)
            
            # Search for existing potential listing
            newpot = True
            for potinfo in model['potential-LAMMPS-KIM'].aslist('potential'):
                if potinfo['key'] == potential.key:
                    newpot = False
                    break
            
            if newpot:            
                # Build potential info
                potinfo = DM()
                model['potential-LAMMPS-KIM'].append('potential', potinfo)
                potinfo['key'] = potential.key
                potinfo['id'] = potential.id
            
            # Add atom info
            if 'atom' not in potinfo:
                noatom = True
                for implementation in potential.implementations:
                    try:
                        sibling = potdb.get_lammps_potential(id = implementation.id)
                    except:
                        pass
                    else:
                        potinfo['atom'] = sibling['potential-LAMMPS']['atom']
                        noatom = False
                        break
            
                if noatom:
                    for element in potential.elements:
                        potinfo.append('atom', DM([('element', element)]))
                    if 'atom' not in potinfo:
                        print(shortcode, 'has no atom info for', potential.id)
    
    # Check if potential is in model after function
    if 'potential' not in model['potential-LAMMPS-KIM']:
        print(shortcode, 'has no matching potential')

# %%
for p in db.potentials:
    print(p.elements)
# Out:
# ['Ar']
# ['Kr']
# ['Ne']
# ['Xe']
# ['Ag']
# ['Al']
# ['Ba']
# ['Ca']
# ['Cr']
# ['Cs']
# ['Cu']
# ['Fe']
# ['K']
# ['Mo']
# ['Na']
# ['Ni']
# ['Pb']
# ['Rb']
# ['Sr']
# ['W']
# ['Ne']
# ['Ar']
# ['Ar', 'Ne']
# ['Cu']
# ['Ni', 'Cu']
# ['Si']
# ['Ag']
# ['Ag', 'Au', 'Cu', 'Ni', 'Pd', 'Pt']
# ['Au']
# ['Cu']
# ['Ni']
# ['Pd']
# ['Pt']
# ['Si']
# ['Mo']
# ['Nb']
# ['Ta']
# ['V']
# ['W']
# ['Ag']
# ['Au']
# ['Cu']
# ['Ni']
# ['Si']
# ['Al']
# ['Cu']
# ['Si']
# ['C']
# ['Ge']
# ['Si']
# ['C']
# ['Si']
# ['Si']
# ['Ag']
# ['Ag', 'Au', 'Cu', 'Ni', 'Pd', 'Pt']
# ['Au']
# ['Cu']
# ['Ni']
# ['Pd']
# ['Pt']
# ['Si']
# ['Si', 'C']
# ['Si', 'Ge']
# ['Cd', 'Te']
# ['Pt']
# ['Cu']
# ['Si', 'C']
# ['Si', 'O']
# ['Si']
# ['Ti']
# ['Si']
# ['Si']
# ['Si']
# ['Al']
# ['Si', 'O']
# ['Si', 'C']
# ['Zr']
# ['Ni']
# ['Ni', 'Al', 'H']
# ['Al', 'Cu']
# ['Nb', 'Ti', 'Al']
# ['Ag']
# ['Al']
# ['Al', 'Ag', 'Au', 'Cu', 'Ni', 'Pd', 'Pt']
# ['Au']
# ['Cu']
# ['Ni']
# ['Pd']
# ['Pt']
# ['Si']
# ['Fe']
# ['Si', 'O']
# ['Al', 'Mg']
# ['Co', 'Al']
# ['Si', 'C']
# ['Si']
# ['Al', 'Mg']
# ['Fe']
# ['Si']
# ['Al', 'Cu']
# ['Al']
# ['Ni']
# ['Al', 'Pb']
# ['Si']
# ['H', 'He', 'C', 'Ar', 'Xe']
# ['Al']
# ['Cr']
# ['Fe']
# ['Mo']
# ['Nb']
# ['Ta']
# ['V']
# ['W']
# ['Fe', 'Cr']
# ['Cu']
# ['Cu']
# ['Al']
# ['Cu']
# ['Pt', 'C']
# ['Ga', 'As']
# ['Ni', 'Al']
# ['Mo']
# ['Nb']
# ['Ta']
# ['V']
# ['W']
# ['Cu', 'Pb']
# ['Ag']
# ['Al']
# ['Au']
# ['Cu']
# ['Ni']
# ['Pb']
# ['Pd']
# ['Pt']
# ['Ta']
# ['C']
# ['Fe']
# ['Fe']
# ['Ga', 'N']
# ['Ni', 'W']
# ['Al']
# ['Ti', 'Al']
# ['Fe', 'P']
# ['Cu', 'Mg']
# ['Cu', 'Ni']
# ['Al']
# ['Ni', 'Al']
# ['Ag']
# ['Al']
# ['Au']
# ['Co']
# ['Cu']
# ['Cu', 'Ag', 'Au']
# ['Fe']
# ['Mg']
# ['Mo']
# ['Ni']
# ['Pb']
# ['Pd']
# ['Pt']
# ['Ta']
# ['Ta', 'Cu']
# ['Ti']
# ['W']
# ['Zr']
# ['Fe']
# ['Si', 'C']
# ['Si', 'C']
# ['Au']
# ['C']
# ['Fe', 'Cu']
# ['Al', 'Fe']
# ['Fe', 'Ni']
# ['Ar']
# ['Ga', 'N']
# ['Al', 'Ni', 'Co']
# ['Al', 'Ni', 'Co']
# ['Fe']
# ['Zn', 'O']
# ['Fe', 'Pt']
# ['Ti']
# ['Zr']
# ['Fe', 'C']
# ['Fe', 'N']
# ['Ga', 'As']
# ['Mg']
# ['Ag']
# ['Cu', 'Ag']
# ['Ca', 'Cd']
# ['Mo']
# ['Nb']
# ['Ta']
# ['V']
# ['W']
# ['He']
# ['Si']
# ['Si']
# ['Fe', 'H']
# ['Zr']
# ['Zr']
# ['Zr']
# ['V', 'Fe']
# ['Cu', 'Zr']
# ['Fe']
# ['Si', 'O']
# ['Cu', 'Zr']
# ['Al', 'Ni']
# ['Si', 'C']
# ['C', 'H', 'O']
# ['In']
# ['Ru']
# ['Cu', 'Ta']
# ['Ti']
# ['Fe', 'C']
# ['Ge']
# ['Cu', 'Zr']
# ['Ti', 'C']
# ['Ti', 'N']
# ['Al']
# ['Cu']
# ['Fe']
# ['Fe', 'Nb']
# ['Fe', 'Ti']
# ['Pd', 'H']
# ['Fe', 'Cu', 'Ni']
# ['Fe', 'Ni']
# ['In', 'P']
# ['Mg', 'Zn']
# ['Ga', 'In']
# ['Ga', 'In', 'N']
# ['Ga', 'N']
# ['In', 'N']
# ['Au', 'Cd']
# ['Cu', 'Ag']
# ['Cu', 'Zr', 'Ag']
# ['Zr', 'Ag']
# ['Fe', 'Ti', 'C']
# ['Mg']
# ['Mg', 'Al']
# ['Fe', 'Mn']
# ['Mn']
# ['Al', 'Mg']
# ['Cu', 'Zr']
# ['H', 'O']
# ['Fe']
# ['V']
# ['W']
# ['Ni', 'Al']
# ['Fe', 'Cr']
# ['U', 'O']
# ['Al']
# ['Cu', 'Ag']
# ['Al']
# ['Au']
# ['Al', 'H']
# ['Ge']
# ['Nb']
# ['Fe', 'Nb', 'C']
# ['Nb', 'C']
# ['Fe', 'Al']
# ['Fe']
# ['Al']
# ['Al']
# ['Al']
# ['Au']
# ['Al', 'Cu']
# ['Fe', 'Cr']
# ['Fe', 'Ni', 'Cr']
# ['Fe']
# ['Si']
# ['Al', 'H']
# ['Ni', 'H']
# ['V', 'H']
# ['U']
# ['U', 'Pu', 'Np', 'O']
# ['Li', 'Na', 'K', 'Rb', 'Cs', 'F', 'Cl', 'Br', 'I']
# ['Co']
# ['Co', 'Al']
# ['Al', 'Si', 'Mg', 'Cu', 'Fe']
# ['Si', 'C']
# ['Li']
# ['Mg', 'Li']
# ['B', 'N', 'C']
# ['Fe', 'P']
# ['P']
# ['Si']
# ['Si']
# ['Ni']
# ['Ni', 'Zr']
# ['Au']
# ['Mo']
# ['Fe']
# ['Co']
# ['Al', 'Mn', 'Pd']
# ['Cd', 'Te']
# ['Cd', 'Te', 'Zn']
# ['Be']
# ['Fe', 'Cr', 'W']
# ['Fe', 'W']
# ['Fe', 'Ni', 'Cr']
# ['Ag', 'Ta', 'O']
# ['Pd', 'Ag', 'H']
# ['Pd', 'Ag', 'H']
# ['Fe', 'C']
# ['V', 'Pd', 'Y']
# ['Y']
# ['W']
# ['W']
# ['W']
# ['Cu']
# ['Cu', 'Ni']
# ['Ta']
# ['Ta']
# ['V', 'Al']
# ['V', 'Al', 'H']
# ['V', 'Ni']
# ['V', 'Ni', 'H']
# ['U', 'Mo', 'Xe']
# ['O', 'Y', 'Zr']
# ['W']
# ['Cd', 'Te', 'Zn']
# ['Zn', 'Cd', 'Hg', 'S', 'Se', 'Te']
# ['W', 'H', 'He']
# ['W', 'H', 'He']
# ['U']
# ['Si', 'C']
# ['Zr', 'H']
# ['Fe', 'C']
# ['C', 'H']
# ['U', 'O']
# ['Si']
# ['Si']
# ['Cd', 'Te', 'Se']
# ['Cu']
# ['Fe']
# ['Ni']
# ['Cu']
# ['Cu']
# ['Cu']
# ['Cu']
# ['Cu']
# ['Cu']
# ['Cu']
# ['Al']
# ['Ce', 'O']
# ['Al']
# ['Al', 'O']
# ['Fe', 'Cr']
# ['Ac']
# ['Ag']
# ['Al']
# ['Am']
# ['Ar']
# ['As']
# ['At']
# ['Au']
# ['B']
# ['Ba']
# ['Be']
# ['Bh']
# ['Bi']
# ['Bk']
# ['Br']
# ['C']
# ['Ca']
# ['Cd']
# ['Ce']
# ['Cf']
# ['Cl']
# ['Cm']
# ['Cn']
# ['Co']
# ['Cr']
# ['Cs']
# ['Cu']
# ['Db']
# ['Ds']
# ['Dy']
# ['Er']
# ['Es']
# ['Eu']
# ['F']
# ['Fe']
# ['Fl']
# ['Fm']
# ['Fr']
# ['Ga']
# ['Gd']
# ['Ge']
# ['H']
# ['He']
# ['Hf']
# ['Hg']
# ['Ho']
# ['Hs']
# ['I']
# ['In']
# ['Ir']
# ['K']
# ['Kr']
# ['La']
# ['Li']
# ['Lr']
# ['Lu']
# ['Lv']
# ['Mc']
# ['Md']
# ['Mg']
# ['Mn']
# ['Mo']
# ['Mt']
# ['N']
# ['Na']
# ['Nb']
# ['Nd']
# ['Ne']
# ['Nh']
# ['Ni']
# ['No']
# ['Np']
# ['O']
# ['Og']
# ['Os']
# ['P']
# ['Pa']
# ['Pb']
# ['Pd']
# ['Pm']
# ['Po']
# ['Pr']
# ['Pt']
# ['Pu']
# ['Ra']
# ['Rb']
# ['Re']
# ['Rf']
# ['Rg']
# ['Rh']
# ['Rn']
# ['Ru']
# ['S']
# ['Sb']
# ['Sc']
# ['Se']
# ['Sg']
# ['Si']
# ['Sm']
# ['Sn']
# ['Sr']
# ['Ta']
# ['Tb']
# ['Tc']
# ['Te']
# ['Th']
# ['Ti']
# ['Tl']
# ['Tm']
# ['Ts']
# ['U']
# ['V']
# ['W']
# ['Xe']
# ['Y']
# ['Yb']
# ['Zn']
# ['Zr']
# ['toy']
# ['Li', 'S']
# ['Ca']
# ['Mg', 'Ca']
# ['Mg', 'Sn']
# ['Mg', 'Y']
# ['Ni', 'Al', 'Co']
# ['Ni', 'Co']
# ['Ni', 'Ti']
# ['Al', 'Ni']
# ['Al', 'Ni', 'O']
# ['Al', 'Sm']
# ['U', 'Zr']
# ['Al']
# ['Al', 'U']
# ['Cu', 'Ta']
# ['Ta']
# ['Al', 'Co']
# ['Ni', 'Al', 'Co']
# ['Ni', 'Co']
# ['Ta']
# ['Na']
# ['Na']
# ['Na']
# ['Ni', 'Zr']
# ['C']
# ['C', 'Cu']
# ['Cu', 'H']
# ['Ni', 'Co']
# ['Cu', 'Zr']
# ['Cu']
# ['Cu']
# ['Cu']
# ['Cu']
# ['Ti']
# ['Al', 'Ti']
# ['Si', 'O']
# ['Ti', 'O']
# ['Ti']
# ['Ti']
# ['Ti']
# ['Ti']
# ['Cs']
# ['K']
# ['Li']
# ['Na']
# ['Rb']
# ['toy']
# ['toy']
# ['toy']
# ['toy']
# ['toy']
# ['toy']
# ['Ni', 'Pd']
# ['Ni']
# ['U', 'N']
# ['Mg']
# ['Mg']
# ['W']
# ['Ti', 'O']
# ['Ni', 'Nb']
# ['Al', 'Cu']
# ['U', 'Si']
# ['Fe', 'Ni', 'Cr']
# ['W', 'Re']
# ['Al']
# ['Mo']
# ['Co', 'Cr']
# ['Co', 'Fe']
# ['Co', 'Mn']
# ['Cr']
# ['Cr', 'Mn']
# ['Mn', 'Ni']
# ['Cu', 'Pt']
# ['Mo']
# ['Ni', 'Pt']
# ['Pt', 'Al']
# ['Pt', 'Co']
# ['Pt', 'Mo']
# ['Pt', 'Ti']
# ['Pt', 'V']
# ['Mg', 'Nd']
# ['Mg', 'Pb']
# ['Ni', 'Al', 'Ti']
# ['Ni', 'Ti']
# ['Li', 'Mn', 'O']
# ['B', 'N']
# ['Ge']
# ['V', 'Ni', 'Ti']
# ['Pt', 'Au']
# ['Au']
# ['Si']
# ['Zr', 'Nb']
# ['Ni', 'H']
# ['Fe', 'Mn']
# ['Mo', 'S']
# ['Ni', 'Cr']
# ['Ni', 'Cr', 'Fe']
# ['Ni', 'Fe']
# ['In', 'Ga', 'N']
# ['Be', 'O']
# ['Co', 'Ni', 'Cr', 'Fe', 'Mn']
# ['Mg', 'Al', 'Zn']
# ['Cu']
# ['Fe']
# ['Ni']
# ['Pb', 'Sn']
# ['Fe', 'Ni', 'Cr', 'Co', 'Cu']
# ['Au', 'Cu']
# ['Cr']
# ['Cr', 'Ni']
# ['Zn']
# ['Zn', 'Mg']
# ['Pd', 'Al']
# ['Pd', 'Co']
# ['Pd', 'Cu']
# ['Pd', 'Fe']
# ['Pd', 'Mo']
# ['Pd', 'Ni']
# ['Pd', 'Ti']
# ['Sn']
# ['Li', 'Co', 'O']
# ['Cu']
# ['Ni']
# ['Ni', 'Mo']
# ['Tb']
# ['Ag', 'Ni']
# ['W', 'Re']
# ['Mg', 'H']
# ['U', 'Mo']
# ['Si', 'Au']
# ['Pb']
# ['Fe', 'Ni', 'Cr']
# ['Al', 'Cu', 'H']
# ['Fe', 'Mn', 'Si', 'C']
# ['Fe', 'O']
# ['W', 'Ta']
# ['Ta', 'He']
# ['Cu', 'Ni']
# ['Mg', 'Zn', 'Ca']
# ['Ni', 'Ti']
# ['Fe', 'Ni', 'Cr']
# ['Cu', 'Zr']
# ['C']
# ['Fe']
# ['Fe', 'Ni', 'Cr', 'Co', 'Al']
# ['Pd', 'C']
# ['Pt', 'C']
# ['Nb', 'Ta', 'W', 'Mo']
# ['Cu', 'N', 'Ti']
# ['Fe']
# ['Co', 'Ti']
# ['Co', 'V']
# ['Si', 'Au', 'Al']
# ['Cu', 'Co']
# ['Cu', 'Mo']
# ['Ta', 'Hf', 'Zr', 'Ti']
# ['C']
# ['C']
# ['C']
# ['Cu']
# ['Cu']
# ['Ge']
# ['Ge']
# ['Li']
# ['Li']
# ['Mo']
# ['Mo']
# ['Ni']
# ['Ni']
# ['Si']
# ['Si']
# ['Au', 'Rh']

# %%
model = DM()

# %%
model = DM('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_115316750986.json')
model['potential-LAMMPS-KIM']['key'] = '235'
#del model['potential-LAMMPS-KIM']['potential']
print(model.json(indent=4))
# Out:
# {
#     "potential-LAMMPS-KIM": {
#         "key": "235",
#         "id": "MO_115316750986",
#         "potential": {
#             "key": "dd581609-b17f-433a-952a-e746a2bf1d4f",
#             "id": "1996--Jacobsen-K-W-Stoltze-P-Norskov-J-K--Al-Ag-Au-Cu-Ni-Pd-Pt",
#             "atom": [
#                 {
#                     "element": "Al"
#                 },
#                 {
#                     "element": "Ag"
#                 },
#                 {
#                     "element": "Au"
#                 },
#                 {
#                     "element": "Cu"
#                 },
#                 {
#                     "element": "Ni"
#                 },
#                 {
#                     "element": "Pd"
#                 },
#                 {
#                     "element": "Pt"
#                 }
#             ]
#         },
#         "full-kim-id": [
#             "EMT_Asap_Standard_JacobsenStoltzeNorskov_1996_AlAgAuCuNiPdPt__MO_115316750986_000",
#             "EMT_Asap_Standard_JacobsenStoltzeNorskov_1996_AlAgAuCuNiPdPt__MO_115316750986_001"
#         ]
#     }
# }

# %%
addpotinfo(db, model)
print(model.json(indent=4))
# Out:
# MO_115316750986 key mismatch with 1996--Jacobsen-K-W-Stoltze-P-Norskov-J-K--Al-Ag-Au-Cu-Ni-Pd-Pt MO_115316750986
# {
#     "potential-LAMMPS-KIM": {
#         "key": "235",
#         "id": "MO_115316750986",
#         "potential": {
#             "key": "dd581609-b17f-433a-952a-e746a2bf1d4f",
#             "id": "1996--Jacobsen-K-W-Stoltze-P-Norskov-J-K--Al-Ag-Au-Cu-Ni-Pd-Pt",
#             "atom": [
#                 {
#                     "element": "Al"
#                 },
#                 {
#                     "element": "Ag"
#                 },
#                 {
#                     "element": "Au"
#                 },
#                 {
#                     "element": "Cu"
#                 },
#                 {
#                     "element": "Ni"
#                 },
#                 {
#                     "element": "Pd"
#                 },
#                 {
#                     "element": "Pt"
#                 }
#             ]
#         },
#         "full-kim-id": [
#             "EMT_Asap_Standard_JacobsenStoltzeNorskov_1996_AlAgAuCuNiPdPt__MO_115316750986_000",
#             "EMT_Asap_Standard_JacobsenStoltzeNorskov_1996_AlAgAuCuNiPdPt__MO_115316750986_001"
#         ]
#     }
# }

# %%
scrape_kim_models()
# Out:
# MO_800536961967
# ['EAM_CubicNaturalSpline_Angelo_Moody_Ni__MO_800536961967_000', 'EAM_CubicNaturalSpline_AngeloMoody_1995_Ni__MO_800536961967_001', 'EAM_CubicNaturalSpline_AngeloMoodyBaskes_1995_Ni__MO_800536961967_002', 'EAM_CubicNaturalSpline_AngeloMoodyBaskes_1995_Ni__MO_800536961967_003']

# %%
{
    "potential-LAMMPS-KIM": {
        "key": "d3694758-2a82-4f0b-933c-d66a7a6aa6a2",
        "id": "MO_004835508849",
        "potential": {
            "key": "bd58ae4c-dc17-40e4-91f0-db3eae46f933",
            "id": "2007--Mendelev-M-I-Ackland-G-J--Zr-3",
            "atom": {
                "element": "Zr",
                "mass": 91.224
            }
        },
        "full-kim-id": "EAM_Dynamo_MendelevAckland_2007v3_Zr__MO_004835508849_000"
    }
}

# %%
shortcode('EAM_Dynamo_HaleWongZimmerman_2008PairHybrid_PdAgH__MO_104806802344_005')
# Out:
# 'MO_104806802344'

# %%
fullids
# Out:
# ['DUNN_WenTadmor_2019v1_C__MO_584345505904_000',
#  'DUNN_WenTadmor_2019v2_C__MO_956135237832_000',
#  'DUNN_WenTadmor_2019v3_C__MO_714772088128_000',
#  'EAM_CubicNaturalSpline_AngeloMoodyBaskes_1995_Ni__MO_800536961967_003',
#  'EAM_CubicNaturalSpline_ErcolessiAdams_1994_Al__MO_800509458712_002',
#  'EAM_Dynamo_Ackland_1987_Au__MO_754413982908_000',
#  'EAM_Dynamo_Ackland_1992_Ti__MO_748534961139_005',
#  'EAM_Dynamo_Ackland_2003_W__MO_141627196590_005',
#  'EAM_Dynamo_AcklandBaconCalder_1997_Fe__MO_142799717516_005',
#  'EAM_Dynamo_AcklandMendelevSrolovitz_2004_FeP__MO_884343146310_005',
#  'EAM_Dynamo_AcklandTichyVitek_1987_Ag__MO_212700056563_005',
#  'EAM_Dynamo_AcklandTichyVitek_1987_Au__MO_104891429740_005',
#  'EAM_Dynamo_AcklandTichyVitek_1987_Cu__MO_179025990738_005',
#  'EAM_Dynamo_AcklandTichyVitek_1987_Ni__MO_977363131043_005',
#  'EAM_Dynamo_AcklandTichyVitek_1987v2_Ag__MO_055919219575_000',
#  'EAM_Dynamo_AcklandTichyVitek_1987v2_Cu__MO_762798677854_000',
#  'EAM_Dynamo_AcklandTichyVitek_1987v2_Ni__MO_769632475533_000',
#  'EAM_Dynamo_AcklandVitek_1990_Cu__MO_642748370624_000',
#  'EAM_Dynamo_AcklandWoodingBacon_1995v2_Zr__MO_398441626455_000',
#  'EAM_Dynamo_AdamsFoilesWolfer_1989_Au__MO_087738844640_000',
#  'EAM_Dynamo_AdamsFoilesWolfer_1989Universal6_Ag__MO_681640899874_000',
#  'EAM_Dynamo_AdamsFoilesWolfer_1989Universal6_Cu__MO_145873824897_000',
#  'EAM_Dynamo_AdamsFoilesWolfer_1989Universal6_Ni__MO_258836200237_000',
#  'EAM_Dynamo_AdamsFoilesWolfer_1989Universal6_Pd__MO_169076431435_000',
#  'EAM_Dynamo_AdamsFoilesWolfer_1989Universal6_Pt__MO_388062184209_000',
#  'EAM_Dynamo_AgrawalMishraWard_2013_Be__MO_404563086984_000',
#  'EAM_Dynamo_AngeloMoodyBaskes_1995_NiAlH__MO_418978237058_005',
#  'EAM_Dynamo_BonnyBakaevTerentyev_2017_WRe__MO_234187151804_000',
#  'EAM_Dynamo_BonnyCastinBullens_2013_FeW__MO_737567242631_000',
#  'EAM_Dynamo_BonnyCastinTerentyev_2013_FeNiCr__MO_763197941039_000',
000',
#  'EAM_Dynamo_ZhouJohnsonWadley_2004NISTretabulation_Zr__MO_380166217430_000',
#  'EAM_Dynamo_ZhouWadleyJohnson_2001_Al__MO_049243498555_000',
#  'EAM_Dynamo_ZhouWadleyJohnson_2001_Cu__MO_380822813353_000',
#  'EAM_Dynamo_ZhouWadleyJohnson_2001_Pt__MO_102190350384_005',
#  'EAM_Dynamo_ZhouWadleyJohnson_2001_W__MO_621445647666_000',
#  'EAM_Dynamo_ZhouZimmermanWong_2008_PdH__MO_114797992931_000',
#  'EAM_Dynamo_ZopeMishin_2003_Al__MO_664470114311_005',
#  'EAM_Dynamo_ZopeMishin_2003_TiAl__MO_117656786760_005',
#  'EAM_ErcolessiAdams_1994_Al__MO_324507536345_003',
#  'EAM_IMD_BrommerBoissieuEuchner_2009_MgZn__MO_710767216198_003',
#  'EAM_IMD_BrommerGaehler_2006A_AlNiCo__MO_122703700223_003',
#  'EAM_IMD_BrommerGaehler_2006B_AlNiCo__MO_128037485276_003',
#  'EAM_IMD_BrommerGaehlerMihalkovic_2007_CaCd__MO_145183423516_003',
#  'EAM_IMD_SchopfBrommerFrigan_2012_AlMnPd__MO_878712978062_003',
#  'EAM_Magnetic2GQuintic_ChiesaDerletDudarev_2011_Fe__MO_140444321607_002',
#  'EAM_MagneticCubic_DerletNguyenDudarev_2007_Mo__MO_424746498193_002',
#  'EAM_MagneticCubic_DerletNguyenDudarev_2007_Nb__MO_218026715338_002',
#  'EAM_MagneticCubic_DerletNguyenDudarev_2007_Ta__MO_261274272789_002',
#  'EAM_MagneticCubic_DerletNguyenDudarev_2007_V__MO_683890323730_002',
#  'EAM_MagneticCubic_DerletNguyenDudarev_2007_W__MO_195478838873_002',
#  'EAM_MagneticCubic_DudarevDerlet_2005_Fe__MO_135034229282_002',
#  'EAM_MagneticCubic_MendelevHanSrolovitz_2003_Fe__MO_856295952425_002',
#  'EAM_Mendelev_2019_CuZr__MO_945018740343_000',
#  'EAM_NN_Johnson_1988_Cu__MO_887933271505_002',
#  'EAM_QuinticClampedSpline_ErcolessiAdams_1994_Al__MO_450093727396_002',
#  'EAM_QuinticClampedSpline_Kim_2021_PtAu__MO_463728687265_000',
#  'EAM_QuinticHermiteSpline_ErcolessiAdams_1994_Al__MO_781138671863_002',
#  'EDIP_BelkoGusakovDorozhkin_2010_Ge__MO_129433059219_001',
#  'EDIP_JustoBazantKaxiras_1998_Si__MO_958932894036_002',
#  'EMT_Asap_MetalGlass_BaileySchiotzJacobsen_2004_CuMg__MO_228059236215_001',
#  'EMT_Asap_MetalGlass_PaduraruKenoufiBailey_2007_CuZr__MO_987541074959_001',
#  'EMT_Asap_Standard_JacobsenStoltzeNorskov_1996_Ag__MO_303974873468_001',
#  'EMT_Asap_Standard_JacobsenStoltzeNorskov_1996_Al__MO_623376124862_001',
#  'EMT_Asap_Standard_JacobsenStoltzeNorskov_1996_AlAgAuCuNiPdPt__MO_115316750986_001',
#  'EMT_Asap_Standard_JacobsenStoltzeNorskov_1996_Au__MO_017524376569_001',
#  'EMT_Asap_Standard_JacobsenStoltzeNorskov_1996_Cu__MO_396616545191_001',
#  'EMT_Asap_Standard_JacobsenStoltzeNorskov_1996_Ni__MO_108408461881_001',
#  'EMT_Asap_Standard_JacobsenStoltzeNorskov_1996_Pd__MO_066802556726_001',
#  'EMT_Asap_Standard_JacobsenStoltzeNorskov_1996_Pt__MO_637493005914_001',
#  'Exp6_KongChakrabarty_1973_ArNe__MO_946046425752_002',
#  'hNN_WenTadmor_2019Grx_C__MO_421038499185_001',
#  'LJ_ElliottAkerson_2015_Universal__MO_959249795837_003',
#  'LJ_Shifted_Bernardes_1958HighCutoff_Ar__MO_242741380554_004',
#  'LJ_Shifted_Bernardes_1958HighCutoff_Kr__MO_923895531627_004',
#  'LJ_Shifted_Bernardes_1958HighCutoff_Ne__MO_966254629593_004',
#  'LJ_Shifted_Bernardes_1958HighCutoff_Xe__MO_796748253903_004',
#  'LJ_Shifted_Bernardes_1958LowCutoff_Ar__MO_720819638419_004',
#  'LJ_Shifted_Bernardes_1958LowCutoff_Kr__MO_995724792024_004',
#  'LJ_Shifted_Bernardes_1958LowCutoff_Ne__MO_466741694288_004',
#  'LJ_Shifted_Bernardes_1958LowCutoff_Xe__MO_648694198005_004',
#  'LJ_Shifted_Bernardes_1958MedCutoff_Ar__MO_126566794224_004',
#  'LJ_Shifted_Bernardes_1958MedCutoff_Kr__MO_984281096460_004',
#  'LJ_Shifted_Bernardes_1958MedCutoff_Ne__MO_160637895352_004',
#  'LJ_Shifted_Bernardes_1958MedCutoff_Xe__MO_849320763277_004',
#  'LJ_Smoothed_Bernardes_1958_Ar__MO_764178710049_001',
#  'LJ_Truncated_Nguyen_2005_Ar__MO_398194508715_001',
#  'MEAM_LAMMPS_AgrawalMirzaeifar_2021_CuC__MO_028979335952_000',
#  'MEAM_LAMMPS_AhmadGrohGhazisaeidi_2018_MgY__MO_135739722270_000',
#  'MEAM_LAMMPS_AlmyrasSangiovanniSarakinos_2019_NAlTi__MO_958395190627_000',
#  'MEAM_LAMMPS_AsadiZaeemNouranian_2015_Cu__MO_390178379548_000',
#  'MEAM_LAMMPS_AsadiZaeemNouranian_2015_Fe__MO_492310898779_000',
#  'MEAM_LAMMPS_AsadiZaeemNouranian_2015_Ni__MO_700541006254_000',
#  'MEAM_LAMMPS_AslamBaskesDickel_2019_FeMnSiC__MO_427873955970_000',
#  'MEAM_LAMMPS_ChoiJoSohn_2018_CoNiCrFeMn__MO_115454747503_000',
#  'MEAM_LAMMPS_ChoiKimSeol_2017_CoCr__MO_410167849923_000',
#  'MEAM_LAMMPS_ChoiKimSeol_2017_CoFe__MO_179158257180_000',
#  'MEAM_LAMMPS_ChoiKimSeol_2017_CoMn__MO_808662295149_000',
#  'MEAM_LAMMPS_ChoiKimSeol_2017_CrMn__MO_671124822359_000',
#  'MEAM_LAMMPS_ChoiKimSeol_2017_NiMn__MO_348689608050_000',
#  'MEAM_LAMMPS_CostaAgrenClavaguera_2007_AlNi__MO_131642768288_000',
#  'MEAM_LAMMPS_CuiGaoCui_2012_LiSi__MO_557492625287_000',
#  'MEAM_LAMMPS_DickelBaskesAslam_2018_MgAlZn__MO_093637366498_000',
#  'MEAM_LAMMPS_DongKimKo_2012_CoAl__MO_099716416216_000',
#  'MEAM_LAMMPS_DoShinLee_2009_GaInN__MO_815057898706_000',
#  'MEAM_LAMMPS_DuLenoskyHennig_2011_Si__MO_883726743759_000',
#  'MEAM_LAMMPS_EtesamiAsadi_2018_Cu__MO_227887284491_000',
#  'MEAM_LAMMPS_EtesamiAsadi_2018_Fe__MO_549900287421_000',
#  'MEAM_LAMMPS_EtesamiAsadi_2018_Ni__MO_937008984446_000',
#  'MEAM_LAMMPS_EtesamiBaskesLaradji_2018_PbSn__MO_162736908871_000',
#  'MEAM_LAMMPS_FernandezPascuet_2014_U__MO_399431830125_000',
#  'MEAM_LAMMPS_GaoOteroAouadi_2013_AgTaO__MO_112077942578_000',
#  'MEAM_LAMMPS_HennigLenoskyTrinkle_2008_Ti__MO_520569947398_000',
#  'MEAM_LAMMPS_HuangDongLiu_2018_Si__MO_050147023220_000',
#  'MEAM_LAMMPS_HuangLiuDuan_2021_HfNbTaTiZr__MO_893505888031_000',
#  'MEAM_LAMMPS_JangKimLee_2018_ZnMg__MO_474962707676_000',
#  'MEAM_LAMMPS_JangSeolLee_2019_CaZnMg__MO_708495328010_000',
#  'MEAM_LAMMPS_JelinekGrohHorstemeyer_2012_AlSiMgCuFe__MO_262519520678_000',
#  'MEAM_LAMMPS_JeongLee_2020_PdC__MO_068985622065_000',
#  'MEAM_LAMMPS_JeongLee_2020_PtC__MO_716623333967_000',
#  'MEAM_LAMMPS_JeongParkDo_2018_PdAl__MO_616482358807_000',
#  'MEAM_LAMMPS_JeongParkDo_2018_PdCo__MO_101997554790_000',
#  'MEAM_LAMMPS_JeongParkDo_2018_PdCu__MO_353393547686_000',
#  'MEAM_LAMMPS_JeongParkDo_2018_PdFe__MO_924736622203_000',
#  'MEAM_LAMMPS_JeongParkDo_2018_PdMo__MO_356501945107_000',
#  'MEAM_LAMMPS_JeongParkDo_2018_PdNi__MO_008996216289_000',
#  'MEAM_LAMMPS_JeongParkDo_2018_PdTi__MO_086900950763_000',
#  'MEAM_LAMMPS_KangEunJun_2014_SiC__MO_477506997611_000',
#  'MEAM_LAMMPS_KangSaLee_2009_ZrAgCu__MO_813575892799_000',
#  'MEAM_LAMMPS_KavousiNovakBaskes_2019_NiTi__MO_050461957184_000',
#  'MEAM_LAMMPS_KimJeonLee_2015_MgCa__MO_611309973581_000',
#  'MEAM_LAMMPS_KimJeonLee_2015_MgSn__MO_935641703527_000',
#  'MEAM_LAMMPS_KimJeonLee_2015_MgY__MO_018428823000_000',
#  'MEAM_LAMMPS_KimJungLee_2009_FeTiC__MO_110119204723_000',
#  'MEAM_LAMMPS_KimJungLee_2010_FeNbC__MO_072689718616_000',
#  'MEAM_LAMMPS_KimJungLee_2012_LiMg__MO_427397414195_000',
#  'MEAM_LAMMPS_KimJungLee_2015_NiAlCo__MO_876687166519_000',
#  'MEAM_LAMMPS_KimKimJung_2016_AlTi__MO_618133763375_000',
#  'MEAM_LAMMPS_KimKimJung_2017_NiAlTi__MO_478967255435_000',
#  'MEAM_LAMMPS_KimKimLee_2009_AlMg__MO_058537087384_000',
#  'MEAM_LAMMPS_KimKoLee_2020_Na__MO_321355778754_000',
#  'MEAM_LAMMPS_KimKoLee_2020_NaSn__MO_329881861557_000',
#  'MEAM_LAMMPS_KimLee_2006_PtFe__MO_343168101490_000',
#  'MEAM_LAMMPS_KimLee_2008_TiC__MO_134206624109_000',
#  'MEAM_LAMMPS_KimLee_2008_TiN__MO_070542625990_000',
#  'MEAM_LAMMPS_KimLee_2017_MgNd__MO_059320827436_000',
#  'MEAM_LAMMPS_KimLee_2017_MgPb__MO_325675357262_000',
#  'MEAM_LAMMPS_KimSeolJi_2017_PtAl__MO_793141037706_000',
#  'MEAM_LAMMPS_KimSeolJi_2017_PtCo__MO_545073984441_000',
#  'MEAM_LAMMPS_KimSeolJi_2017_PtCu__MO_070797404269_000',
#  'MEAM_LAMMPS_KimSeolJi_2017_PtMo__MO_831380044253_000',
#  'MEAM_LAMMPS_KimSeolJi_2017_PtNi__MO_020840179467_000',
#  'MEAM_LAMMPS_KimSeolJi_2017_PtTi__MO_280985530673_000',
#  'MEAM_LAMMPS_KimSeolJi_2017_PtV__MO_912978207512_000',
#  'MEAM_LAMMPS_KimShinLee_2009_FeMn__MO_058735400462_000',
#  'MEAM_LAMMPS_KoGrabowskiNeugebauer_2015_NiTi__MO_663355627503_000',
#  'MEAM_LAMMPS_KoJimLee_2012_FeP__MO_179420363944_000',
#  'MEAM_LAMMPS_KoKimKwon_2018_Sn__MO_129364204512_000',
#  'MEAM_LAMMPS_KoLee_2013_VPdY__MO_046547823135_000',
#  'MEAM_LAMMPS_KoShimLee_2011_AlH__MO_127847080751_000',
#  'MEAM_LAMMPS_KoShimLee_2011_NiH__MO_091278480940_000',
#  'MEAM_LAMMPS_Lee_2006_FeC__MO_856956178669_000',
#  'MEAM_LAMMPS_LeeJang_2007_FeH__MO_095610951957_000',
#  'MEAM_LAMMPS_LeeLee_2010_FeAl__MO_332211522050_000',
#  'MEAM_LAMMPS_LeeLee_2014_ZrH__MO_946208788356_000',
#  'MEAM_LAMMPS_LeeLeeKim_2006_FeN__MO_432861766738_000',
#  'MEAM_LAMMPS_LeeShim_2004_NiCu__MO_409065472403_000',
#  'MEAM_LAMMPS_LeeWirthShim_2005_FeCu__MO_063626065437_000',
#  'MEAM_LAMMPS_Lenosky_2017_W__MO_999198119251_000',
#  'MEAM_LAMMPS_LenoskySadighAlonso_2000_Si__MO_533426548156_000',
#  'MEAM_LAMMPS_LiyanageKimHouze_2014_FeC__MO_075279800195_000',
#  'MEAM_LAMMPS_MaiselKoZhang_2017_VNiTi__MO_744610363128_000',
#  'MEAM_LAMMPS_MirazDhariwalMeng_2020_CuNTi__MO_122936827583_000',
#  'MEAM_LAMMPS_NouranianTschoppGwaltney_2014_CH__MO_354152387712_000',
#  'MEAM_LAMMPS_OhSeolLee_2020_CoTi__MO_862371677648_000',
#  'MEAM_LAMMPS_OhSeolLee_2020_CoV__MO_771146361182_000',
#  'MEAM_LAMMPS_ParkFellingerLenosky_2012_Mo__MO_269937397263_000',
004',
#  'Morse_Shifted_GirifalcoWeizer_1959LowCutoff_Mo__MO_228581001644_004',
#  'Morse_Shifted_GirifalcoWeizer_1959LowCutoff_Na__MO_707981543254_004',
#  'Morse_Shifted_GirifalcoWeizer_1959LowCutoff_Ni__MO_322509103239_004',
#  'Morse_Shifted_GirifalcoWeizer_1959LowCutoff_Pb__MO_534638645497_004',
#  'Morse_Shifted_GirifalcoWeizer_1959LowCutoff_Rb__MO_754498969542_004',
#  'Morse_Shifted_GirifalcoWeizer_1959LowCutoff_Sr__MO_801083489225_004',
#  'Morse_Shifted_GirifalcoWeizer_1959LowCutoff_W__MO_489351836217_004',
#  'Morse_Shifted_GirifalcoWeizer_1959MedCutoff_Ag__MO_861893969202_004',
#  'Morse_Shifted_GirifalcoWeizer_1959MedCutoff_Al__MO_279544746097_004',
#  'Morse_Shifted_GirifalcoWeizer_1959MedCutoff_Ba__MO_229241184339_004',
#  'Morse_Shifted_GirifalcoWeizer_1959MedCutoff_Ca__MO_562200212426_004',
#  'Morse_Shifted_GirifalcoWeizer_1959MedCutoff_Cr__MO_245813471114_004',
#  'Morse_Shifted_GirifalcoWeizer_1959MedCutoff_Cs__MO_999639780744_004',
#  'Morse_Shifted_GirifalcoWeizer_1959MedCutoff_Cu__MO_173787283511_004',
#  'Morse_Shifted_GirifalcoWeizer_1959MedCutoff_Fe__MO_984358344196_004',
#  'Morse_Shifted_GirifalcoWeizer_1959MedCutoff_K__MO_202712315930_004',
#  'Morse_Shifted_GirifalcoWeizer_1959MedCutoff_Mo__MO_534363225491_004',
#  'Morse_Shifted_GirifalcoWeizer_1959MedCutoff_Na__MO_636041334617_004',
#  'Morse_Shifted_GirifalcoWeizer_1959MedCutoff_Ni__MO_758825945924_004',
#  'Morse_Shifted_GirifalcoWeizer_1959MedCutoff_Pb__MO_958424213898_004',
#  'Morse_Shifted_GirifalcoWeizer_1959MedCutoff_Rb__MO_147245690895_004',
#  'Morse_Shifted_GirifalcoWeizer_1959MedCutoff_Sr__MO_964297938209_004',
#  'Morse_Shifted_GirifalcoWeizer_1959MedCutoff_W__MO_390128289865_004',
#  'Morse_Shifted_Glyde_1970_Ne__MO_169434419764_004',
#  'Morse_Shifted_Jelinek_1972_Ar__MO_831902330215_004',
#  'Morse_SigmoidalSmoothed_Jelinek_1972_Ar__MO_071460865933_002',
#  'SNAP_ChenDengTran_2017_Mo__MO_698578166685_000',
#  'SNAP_LiChenZheng_2019_NbTaWMo__MO_560387080449_000',
#  'SNAP_LiHuChen_2018_Cu__MO_529419924683_000',
#  'SNAP_LiHuChen_2018_Ni__MO_913991514986_000',
#  'SNAP_LiHuChen_2018_NiMo__MO_468686727341_000',
#  'SNAP_ThompsonSwilerTrott_2015_Ta__MO_359768485367_000',
#  'SNAP_ZuoChenLi_2019_Cu__MO_931672895580_000',
#  'SNAP_ZuoChenLi_2019_Ge__MO_183216355174_000',
#  'SNAP_ZuoChenLi_2019_Li__MO_732106099012_000',
#  'SNAP_ZuoChenLi_2019_Mo__MO_014123846623_000',
#  'SNAP_ZuoChenLi_2019_Ni__MO_365106510449_000',
#  'SNAP_ZuoChenLi_2019_Si__MO_869330304805_000',
#  'SNAP_ZuoChenLi_2019quadratic_Cu__MO_265210066873_000',
#  'SNAP_ZuoChenLi_2019quadratic_Ge__MO_766484508139_000',
#  'SNAP_ZuoChenLi_2019quadratic_Li__MO_041269750353_000',
#  'SNAP_ZuoChenLi_2019quadratic_Mo__MO_692442138123_000',
#  'SNAP_ZuoChenLi_2019quadratic_Ni__MO_263593395744_000',
#  'SNAP_ZuoChenLi_2019quadratic_Si__MO_721469752060_000',
#  'SW_BalamaneHaliciogluTiller_1992_Si__MO_113686039439_004',
#  'SW_BalamaneHauchShi_2017Brittle_Si__MO_381114941873_002',
#  'SW_BereSerra_2006_GaN__MO_861114678890_000',
#  'SW_HauchHollandMarder_1999Brittle_Si__MO_119167353542_004',
#  'SW_LeeHwang_2012GGA_Si__MO_040570764911_000',
#  'SW_LeeHwang_2012LDA_Si__MO_517338295712_000',
#  'SW_MX2_WenShirodkarPlechac_2017_MoS__MO_201919462778_001',
#  'SW_StillingerWeber_1985_Si__MO_405512056662_005',
#  'SW_WangStroudMarkworth_1989_CdTe__MO_786496821446_000',
#  'SW_ZhangXieHu_2014OptimizedSW1_Si__MO_800412945727_004',
#  'SW_ZhangXieHu_2014OptimizedSW2_Si__MO_475612090600_004',
#  'SW_ZhouWardMartin_2013_CdTeZnSeHgS__MO_503261197030_002',
#  'Tersoff_LAMMPS_AlbeNordlundAverback_2002_PtC__MO_500121566391_003',
#  'Tersoff_LAMMPS_AlbeNordlundNord_2002_GaAs__MO_799020228312_003',
#  'Tersoff_LAMMPS_ErhartAlbe_2005_SiC__MO_903987585848_004',
#  'Tersoff_LAMMPS_ErhartAlbe_2005SiII_SiC__MO_408791041969_003',
#  'Tersoff_LAMMPS_ErhartJuslinGoy_2006_ZnO__MO_616776018688_003',
#  'Tersoff_LAMMPS_MuellerErhartAlbe_2007_Fe__MO_137964310702_003',
#  'Tersoff_LAMMPS_NordAlbeErhart_2003_GaN__MO_612061685362_003',
#  'Tersoff_LAMMPS_Tersoff_1988_C__MO_579868029681_003',
#  'Tersoff_LAMMPS_Tersoff_1988T2_Si__MO_245095684871_003',
#  'Tersoff_LAMMPS_Tersoff_1988T3_Si__MO_186459956893_003',
#  'Tersoff_LAMMPS_Tersoff_1989_SiC__MO_171585019474_003',
#  'Tersoff_LAMMPS_Tersoff_1989_SiGe__MO_350526375143_003',
#  'ThreeBodyBondOrder_KDS_KhorDasSarma_1988_C__MO_454320668790_000',
#  'ThreeBodyBondOrder_KDS_KhorDasSarma_1988_Ge__MO_216597146527_000',
#  'ThreeBodyBondOrder_KDS_KhorDasSarma_1988_Si__MO_722489435928_000',
#  'ThreeBodyBondOrder_PPM_PurjaPunMishin_2017_Si__MO_566683736730_000',
#  'ThreeBodyBondOrder_WR_WangRockett_1991_Si__MO_081872846741_000',
#  'ThreeBodyCluster_BH_BiswasHamann_1987_Si__MO_019616213550_000',
#  'ThreeBodyCluster_Gong_Gong_1993_Si__MO_407755720412_000',
#  'ThreeBodyCluster_KP_KaxirasPandey_1988_Si__MO_072486242437_000',
#  'ThreeBodyCluster_SRS_StephensonRadnySmith_1996_Si__MO_604248666067_000',
#  'TIDP_RajanWarnerCurtin_2016A_User01__MO_514760222899_001',
#  'TIDP_RajanWarnerCurtin_2016B_User01__MO_217710069583_001',
#  'TIDP_RajanWarnerCurtin_2016C_User01__MO_072437275969_001',
#  'TIDP_RajanWarnerCurtin_2016D_User01__MO_791486224463_001',
#  'TIDP_RajanWarnerCurtin_2016E_User01__MO_971845881377_001',
#  'TIDP_RajanWarnerCurtin_2016F_User01__MO_246297839798_001',
#  'TT_Modified_HellmannBichVogel_2007_He__MO_126942667206_002']

# %%
r.text.index('not here')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-c8e51622c6c7> in <module>
# ----> 1 r.text.index('not here')
#
# ValueError: substring not found

# %%
records = {}
for filename in Path(db.localpath, 'potential_LAMMPS_KIM').glob('MO_*'):
    if filename.suffix.lower() not in ['.json', '.xml']:
        continue
    recordname = filename.stem
    records[recordname] = filename
  
print(len(records), 'local potential_LAMMPS_KIM records found')
# Out:
# 450 local potential_LAMMPS_KIM records found

# %%
records
# Out:
# {'MO_004835508849': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_004835508849.json'),
#  'MO_008996216289': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_008996216289.json'),
#  'MO_010059867259': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_010059867259.json'),
#  'MO_010613863288': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_010613863288.json'),
#  'MO_014123846623': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_014123846623.json'),
#  'MO_017524376569': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_017524376569.json'),
#  'MO_018428823000': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_018428823000.json'),
#  'MO_019616213550': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO
WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_942551040047.json'),
#  'MO_945018740343': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_945018740343.json'),
#  'MO_945691923444': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_945691923444.json'),
#  'MO_946046425752': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_946046425752.json'),
#  'MO_946208788356': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_946208788356.json'),
#  'MO_946831081299': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_946831081299.json'),
#  'MO_947112899505': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_947112899505.json'),
#  'MO_950828638160': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_950828638160.json'),
#  'MO_956135237832': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_956135237832.json'),
#  'MO_958395190627': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_958395190627.json'),
#  'MO_958424213898': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_958424213898.json'),
#  'MO_958932894036': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_958932894036.json'),
#  'MO_959249795837': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_959249795837.json'),
#  'MO_960699513424': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_960699513424.json'),
#  'MO_964297938209': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_964297938209.json'),
#  'MO_966254629593': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_966254629593.json'),
#  'MO_971845881377': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_971845881377.json'),
#  'MO_977363131043': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_977363131043.json'),
#  'MO_984281096460': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_984281096460.json'),
#  'MO_984358344196': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_984358344196.json'),
#  'MO_987541074959': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_987541074959.json'),
#  'MO_988703794028': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_988703794028.json'),
#  'MO_993644691224': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_993644691224.json'),
#  'MO_995724792024': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_995724792024.json'),
#  'MO_999198119251': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_999198119251.json'),
#  'MO_999639780744': WindowsPath('C:/Users/lmh1/Documents/library/potential_LAMMPS_KIM/MO_999639780744.json')}

# %%
template = 'potential_LAMMPS_KIM'
for title in records:
    content = DM(records[title]).xml()

    db.upload_record(template, content, title, verbose=True)
# Out:
# record MO_004835508849 (605b65a326ed1e002a28ef03) successfully uploaded.
# record MO_008996216289 (605b65a726ed1e003828eef9) successfully uploaded.
# record MO_010059867259 (605b65aa26ed1e003928eeef) successfully uploaded.
# record MO_010613863288 (605b65ad26ed1e003b28eef4) successfully uploaded.
# record MO_014123846623 (605b65b226ed1e003a28eeee) successfully uploaded.
# record MO_017524376569 (605b65b526ed1e002a28ef07) successfully uploaded.
# record MO_018428823000 (605b65b926ed1e003828eefd) successfully uploaded.
# record MO_019616213550 (605b65bc26ed1e003928eef3) successfully uploaded.
# record MO_019873715786 (605b65be26ed1e003b28eef8) successfully uploaded.
# record MO_020840179467 (605b65c226ed1e003a28eef2) successfully uploaded.
# record MO_020851069572 (605b65c826ed1e002a28ef0b) successfully uploaded.
# record MO_022920256108 (605b65cb26ed1e003828ef01) successfully uploaded.
# record MO_028979335952 (605b65ce26ed1e003928eef7) successfully uploaded.
# record MO_034823476734 (605b65d226ed1e003b28eefc) successfully uploaded.
# record MO_040570764911 (605b65d626ed1e003a28eef6) successfully uploaded.
# record MO_041269750353 (605b65d926ed1e002a28ef0f) successfully uploaded.
# record MO_042691367780 (605b65de26ed1e003828ef05) successfully uploaded.
# record MO_046547823135 (605b65e226ed1e003928eefb) successfully uploaded.
# record MO_046576227003 (605b65e526ed1e003b28ef00) successfully uploaded.
# record MO_047308317761 (605b65e926ed1e003a28eefa) successfully uploaded.
# record MO_048172193005 (605b65ec26ed1e002a28ef13) successfully uploaded.
# record MO_049243498555 (605b65f026ed1e003828ef09) successfully uploaded.
# record MO_050147023220 (605b65f326ed1e003928eeff) successfully uploaded.
# record MO_050461957184 (605b65f726ed1e003b28ef04) successfully uploaded.
# record MO_051157671505 (605b65fa26ed1e003a28eefe) successfully uploaded.
# record MO_055919219575 (605b65fd26ed1e002a28ef17) successfully uploaded.
# record MO_058537087384 (605b660026ed1e003828ef0d) successfully uploaded.
# record MO_058735400462 (605b660326ed1e003928ef03) successfully uploaded.
# record MO_059320827436 (605b660726ed1e003b28ef08) successfully uploaded.
# record MO_060567868558 (605b660a26ed1e003a28ef02) successfully uploaded.
# record MO_063626065437 (605b660d26ed1e002a28ef1b) successfully uploaded.
# record MO_066802556726 (605b661026ed1e003828ef11) successfully uploaded.
# record MO_068985622065 (605b661326ed1e003928ef07) successfully uploaded.
# record MO_070542625990 (605b661726ed1e003b28ef0c) successfully uploaded.
# record MO_070797404269 (605b661a26ed1e003a28ef06) successfully uploaded.
# record MO_071460865933 (605b661d26ed1e002a28ef1f) successfully uploaded.
# record MO_072437275969 (605b662026ed1e003828ef15) successfully uploaded.
# record MO_072444764353 (605b662326ed1e003928ef0b) successfully uploaded.
# record MO_072486242437 (605b662626ed1e003b28ef10) successfully uploaded.
# record MO_072689718616 (605b662a26ed1e003a28ef0a) successfully uploaded.
# record MO_075279800195 (605b662d26ed1e002a28ef23) successfully uploaded.
# record MO_080526771943 (605b663026ed1e003828ef19) successfully uploaded.
# record MO_081872846741 (605b663326ed1e003928ef0f) successfully uploaded.
# record MO_086900950763 (605b663626ed1e003b28ef14) successfully uploaded.
# record MO_087738844640 (605b663b26ed1e003a28ef0e) successfully uploaded.
# record MO_091278480940 (605b664026ed1e002a28ef27) successfully uploaded.
# record MO_094065024556 (605b664326ed1e003828ef1d) successfully uploaded.
# record MO_095610951957 (605b664626ed1e003928ef13) successfully uploaded.
# record MO_097471813275 (605b664a26ed1e003b28ef18) successfully uploaded.
# record MO_099716416216 (605b664d26ed1e003a28ef12) successfully uploaded.
# record MO_101214310689 (605b665126ed1e002a28ef2b) successfully uploaded.
# record MO_101966451181 (605b665526ed1e003828ef21) successfully uploaded.
# record MO_101997554790 (605b665a26ed1e003928ef17) successfully uploaded.
# record MO_102133002179 (605b665e26ed1e003b28ef1c) successfully uploaded.
# record MO_102190350384 (605b666126ed1e003a28ef16) successfully uploaded.
# record MO_103054252769 (605b666426ed1e002a28ef2f) successfully uploaded.
# record MO_103270551167 (605b666926ed1e003828ef25) successfully uploaded.
# record MO_104806802344 (605b666d26ed1e003628ef05) successfully uploaded.
# record MO_104891429740 (605b667026ed1e003d28eeec) successfully uploaded.
# record MO_105449194206 (605b667426ed1e003528eef1) successfully uploaded.
# record MO_106969701023 (605b667726ed1e003728ef03) successfully uploaded.
# record MO_108408461881 (605b667a26ed1e003c28eef5) successfully uploaded.
# record MO_108983864770 (605b667f26ed1e003628ef09) successfully uploaded.
# record MO_109933561507 (605b668226ed1e003d28eef0) successfully uploaded.
# record MO_110119204723 (605b668626ed1e003528eef5) successfully uploaded.
# record MO_110256178378 (605b668926ed1e003728ef07) successfully uploaded.
# record MO_111986436268 (605b668c26ed1e003c28eef9) successfully uploaded.
# record MO_112077942578 (605b669026ed1e003628ef0d) successfully uploaded.
# record MO_113686039439 (605b669426ed1e003d28eef4) successfully uploaded.
# record MO_114077951467 (605b669726ed1e003528eef9) successfully uploaded.
# record MO_114797992931 (605b669b26ed1e003728ef0b) successfully uploaded.
# record MO_115316750986 (605b669f26ed1e003c28eefd) successfully uploaded.
# record MO_115454747503 (605b66a226ed1e003628ef11) successfully uploaded.
# record MO_116920074573 (605b66a726ed1e003d28eef8) successfully uploaded.
# record MO_117656786760 (605b66ab26ed1e003528eefd) successfully uploaded.
# record MO_117938381510 (605b66ae26ed1e003d28eefc) successfully uploaded.
# record MO_118428466217 (605b66b226ed1e003728ef0f) successfully uploaded.
# record MO_119135752160 (605b66b526ed1e003628ef15) successfully uploaded.
# record MO_119167353542 (605b66b826ed1e003d28ef00) successfully uploaded.
# record MO_120596890176 (605b66bc26ed1e003528ef01) successfully uploaded.
# record MO_120808805541 (605b66be26ed1e003728ef13) successfully uploaded.
# record MO_122703700223 (605b66c226ed1e003c28ef01) successfully uploaded.
# record MO_122936827583 (605b66c526ed1e003628ef19) successfully uploaded.
# record MO_123629422045 (605b66c726ed1e003d28ef04) successfully uploaded.
# record MO_126566794224 (605b66cc26ed1e003528ef05) successfully uploaded.
# record MO_126942667206 (605b66cf26ed1e003728ef17) successfully uploaded.
# record MO_127245782811 (605b66d326ed1e003c28ef05) successfully uploaded.
# record MO_127847080751 (605b66d726ed1e003628ef1d) successfully uploaded.
# record MO_128037485276 (605b66da26ed1e003928ef1b) successfully uploaded.
# record MO_128703483589 (605b66dd26ed1e003a28ef1a) successfully uploaded.
# record MO_129364204512 (605b66e026ed1e003b28ef20) successfully uploaded.
# record MO_129433059219 (605b66e326ed1e003a28ef1e) successfully uploaded.
# record MO_130046220009 (605b66e626ed1e002a28ef33) successfully uploaded.
# record MO_131620013077 (605b66e926ed1e003828ef29) successfully uploaded.
# record MO_131642768288 (605b66ec26ed1e003928ef1f) successfully uploaded.
# record MO_131650261510 (605b66ef26ed1e003b28ef24) successfully uploaded.
# record MO_134206624109 (605b66f226ed1e003a28ef22) successfully uploaded.
# record MO_135034229282 (605b66f526ed1e002a28ef37) successfully uploaded.
# record MO_135739722270 (605b66f726ed1e003828ef2d) successfully uploaded.
# record MO_137404467969 (605b66fa26ed1e003928ef23) successfully uploaded.
# record MO_137572817842 (605b66fd26ed1e003b28ef28) successfully uploaded.
# record MO_137719994600 (605b670126ed1e003a28ef26) successfully uploaded.
# record MO_137964310702 (605b670526ed1e002a28ef3b) successfully uploaded.
# record MO_140175748626 (605b670826ed1e003828ef31) successfully uploaded.
# record MO_140444321607 (605b670c26ed1e003b28ef2c) successfully uploaded.
# record MO_141627196590 (605b670f26ed1e002a28ef3f) successfully uploaded.
# record MO_142799717516 (605b671226ed1e003628ef21) successfully uploaded.
# record MO_143487634619 (605b671526ed1e003d28ef08) successfully uploaded.
# record MO_143977152728 (605b671826ed1e003528ef09) successfully uploaded.
# record MO_144828415103 (605b671b26ed1e002a28ef43) successfully uploaded.
# record MO_145183423516 (605b671e26ed1e003c28ef09) successfully uploaded.
# record MO_145522277939 (605b672026ed1e003928ef27) successfully uploaded.
# record MO_145873824897 (605b672526ed1e003d28ef0c) successfully uploaded.
# record MO_147245690895 (605b672826ed1e003528ef0d) successfully uploaded.
# record MO_147603128437 (605b672b26ed1e002a28ef47) successfully uploaded.
# record MO_149104665840 (605b672e26ed1e003c28ef0d) successfully uploaded.
# record MO_149316865608 (605b673126ed1e003928ef2b) successfully uploaded.
# record MO_151002396060 (605b673426ed1e003d28ef10) successfully uploaded.
# record MO_154399806462 (605b673726ed1e003528ef11) successfully uploaded.
# record MO_159753408472 (605b673b26ed1e002a28ef4b) successfully uploaded.
# record MO_160637895352 (605b673f26ed1e003c28ef11) successfully uploaded.
# record MO_162036141261 (605b674326ed1e003928ef2f) successfully uploaded.
# record MO_162736908871 (605b674626ed1e003d28ef14) successfully uploaded.
# record MO_169076431435 (605b674a26ed1e003528ef15) successfully uploaded.
# record MO_169434419764 (605b674e26ed1e002a28ef4f) successfully uploaded.
# record MO_171585019474 (605b675126ed1e003c28ef15) successfully uploaded.
# record MO_173248269481 (605b675626ed1e003928ef33) successfully uploaded.
# record MO_173787283511 (605b675926ed1e003d28ef18) successfully uploaded.
# record MO_179025990738 (605b675d26ed1e003528ef19) successfully uploaded.
# record MO_179158257180 (605b676226ed1e002a28ef53) successfully uploaded.
# record MO_179420363944 (605b676426ed1e003c28ef19) successfully uploaded.
# record MO_183216355174 (605b676926ed1e003928ef37) successfully uploaded.
# record MO_186459956893 (605b676d26ed1e003d28ef1c) successfully uploaded.
# record MO_187111446479 (605b677226ed1e003528ef1d) successfully uploaded.
# record MO_188701096956 (605b677526ed1e002a28ef57) successfully uploaded.
# record MO_195478838873 (605b677926ed1e003c28ef1d) successfully uploaded.
# record MO_201919462778 (605b678b26ed1e003928ef3b) successfully uploaded.
# record MO_202712315930 (605b678f26ed1e003d28ef20) successfully uploaded.
# record MO_204305659515 (605b679226ed1e003528ef21) successfully uploaded.
# record MO_212700056563 (605b679526ed1e002a28ef5b) successfully uploaded.
# record MO_216597146527 (605b679926ed1e003c28ef21) successfully uploaded.
# record MO_217710069583 (605b679d26ed1e003928ef3f) successfully uploaded.
# record MO_218026715338 (605b67a026ed1e003d28ef24) successfully uploaded.
# record MO_227887284491 (605b67a326ed1e003528ef25) successfully uploaded.
# record MO_228059236215 (605b67a626ed1e002a28ef5f) successfully uploaded.
# record MO_228280943430 (605b67a926ed1e003c28ef25) successfully uploaded.
# record MO_228581001644 (605b67ac26ed1e003928ef43) successfully uploaded.
# record MO_229241184339 (605b67ae26ed1e003d28ef28) successfully uploaded.
# record MO_230319944007 (605b67b226ed1e003528ef29) successfully uploaded.
# record MO_234187151804 (605b67b526ed1e002a28ef63) successfully uploaded.
# record MO_242741380554 (605b67b726ed1e003c28ef29) successfully uploaded.
# record MO_245095684871 (605b67ba26ed1e003928ef47) successfully uploaded.
# record MO_245813471114 (605b67be26ed1e003d28ef2c) successfully uploaded.
# record MO_246297839798 (605b67c226ed1e003528ef2d) successfully uploaded.
# record MO_247800397145 (605b67c426ed1e002a28ef67) successfully uploaded.
# record MO_249706810527 (605b67c726ed1e003c28ef2d) successfully uploaded.
# record MO_255315407910 (605b67ca26ed1e003928ef4b) successfully uploaded.
# record MO_256406354561 (605b67ce26ed1e003d28ef30) successfully uploaded.
# record MO_258836200237 (605b67d126ed1e003528ef31) successfully uploaded.
# record MO_260546967793 (605b67d426ed1e002a28ef6b) successfully uploaded.
# record MO_261274272789 (605b67d926ed1e003c28ef31) successfully uploaded.
# record MO_262519520678 (605b67dc26ed1e003928ef4f) successfully uploaded.
# record MO_263593395744 (605b67e026ed1e003d28ef34) successfully uploaded.
# record MO_265210066873 (605b67e326ed1e003528ef35) successfully uploaded.
# record MO_267721408934 (605b67e926ed1e002a28ef6f) successfully uploaded.
# record MO_269937397263 (605b67ee26ed1e003c28ef35) successfully uploaded.
# record MO_270337113239 (605b67f326ed1e003928ef53) successfully uploaded.
# record MO_271256517527 (605b67f626ed1e003d28ef38) successfully uploaded.
# record MO_279544746097 (605b67fa26ed1e003528ef39) successfully uploaded.
# record MO_280985530673 (605b67fe26ed1e002a28ef73) successfully uploaded.
# record MO_284963179498 (605b680126ed1e003c28ef39) successfully uploaded.
# record MO_286137913440 (605b680526ed1e003928ef57) successfully uploaded.
# record MO_292520929154 (605b680826ed1e003d28ef3c) successfully uploaded.
# record MO_303974873468 (605b680d26ed1e003528ef3d) successfully uploaded.
# record MO_306032198193 (605b681126ed1e002a28ef77) successfully uploaded.
# record MO_309653492217 (605b681426ed1e003c28ef3d) successfully uploaded.
# record MO_313717476091 (605b681726ed1e003928ef5b) successfully uploaded.
# record MO_315820974149 (605b681a26ed1e003d28ef40) successfully uploaded.
# record MO_316045643888 (605b681e26ed1e003528ef41) successfully uploaded.
# record MO_318213562153 (605b682126ed1e002a28ef7b) successfully uploaded.
# record MO_321233176498 (605b682426ed1e003c28ef41) successfully uploaded.
# record MO_321355778754 (605b682926ed1e003928ef5f) successfully uploaded.
# record MO_322509103239 (605b682c26ed1e003d28ef44) successfully uploaded.
# record MO_324507536345 (605b682e26ed1e003528ef45) successfully uploaded.
# record MO_325675357262 (605b683226ed1e002a28ef7f) successfully uploaded.
# record MO_329881861557 (605b683626ed1e003c28ef45) successfully uploaded.
# record MO_330376344314 (605b683b26ed1e003928ef63) successfully uploaded.
# record MO_331285495617 (605b684126ed1e003d28ef48) successfully uploaded.
# record MO_332211522050 (605b684426ed1e003528ef49) successfully uploaded.
# record MO_338600200739 (605b684826ed1e002a28ef83) successfully uploaded.
# record MO_343168101490 (605b684b26ed1e003c28ef49) successfully uploaded.
# record MO_344044439515 (605b684f26ed1e003928ef67) successfully uploaded.
# record MO_344724145339 (605b685326ed1e003d28ef4c) successfully uploaded.
# record MO_346334655118 (605b685526ed1e003528ef4d) successfully uploaded.
# record MO_348689608050 (605b685926ed1e002a28ef87) successfully uploaded.
# record MO_350526375143 (605b685c26ed1e003c28ef4d) successfully uploaded.
# record MO_353393547686 (605b685f26ed1e003928ef6b) successfully uploaded.
# record MO_354152387712 (605b686326ed1e003d28ef50) successfully uploaded.
# record MO_356501945107 (605b686726ed1e003528ef51) successfully uploaded.
# record MO_359768485367 (605b686a26ed1e002a28ef8b) successfully uploaded.
# record MO_360068930164 (605b686d26ed1e003c28ef51) successfully uploaded.
# record MO_365106510449 (605b687026ed1e003928ef6f) successfully uploaded.
# record MO_370271093517 (605b687326ed1e003d28ef54) successfully uploaded.
# record MO_380166217430 (605b687726ed1e003528ef55) successfully uploaded.
# record MO_380272712420 (605b687b26ed1e002a28ef8f) successfully uploaded.
# record MO_380822813353 (605b688a26ed1e003c28ef55) successfully uploaded.
# record MO_381114941873 (605b688d26ed1e003928ef73) successfully uploaded.
# record MO_381861218831 (605b689026ed1e003d28ef58) successfully uploaded.
# record MO_388062184209 (605b689326ed1e003528ef59) successfully uploaded.
# record MO_390128289865 (605b689626ed1e002a28ef93) successfully uploaded.
# record MO_390178379548 (605b689a26ed1e003c28ef59) successfully uploaded.
# record MO_394669891912 (605b689d26ed1e003928ef77) successfully uploaded.
# record MO_396616545191 (605b68a126ed1e003d28ef5c) successfully uploaded.
# record MO_398194508715 (605b68a426ed1e003528ef5d) successfully uploaded.
# record MO_398441626455 (605b68a726ed1e002a28ef97) successfully uploaded.
# record MO_399431830125 (605b68ab26ed1e003c28ef5d) successfully uploaded.
# record MO_400591584784 (605b68af26ed1e003928ef7b) successfully uploaded.
# record MO_404563086984 (605b68b326ed1e003d28ef60) successfully uploaded.
# record MO_405512056662 (605b68b726ed1e003528ef61) successfully uploaded.
# record MO_407755720412 (605b68bc26ed1e002a28ef9b) successfully uploaded.
# record MO_408791041969 (605b68bf26ed1e003c28ef61) successfully uploaded.
# record MO_409065472403 (605b68c226ed1e003928ef7f) successfully uploaded.
# record MO_410167849923 (605b68c626ed1e003d28ef64) successfully uploaded.
# record MO_411020944797 (605b68c926ed1e003528ef65) successfully uploaded.
# record MO_411692133366 (605b68cc26ed1e002a28ef9f) successfully uploaded.
# record MO_411898953661 (605b68cf26ed1e003c28ef65) successfully uploaded.
# record MO_418978237058 (605b68d526ed1e003928ef83) successfully uploaded.
# record MO_421038499185 (605b68d826ed1e003d28ef68) successfully uploaded.
# record MO_424746498193 (605b68db26ed1e003528ef69) successfully uploaded.
# record MO_426403318662 (605b68e026ed1e002a28efa3) successfully uploaded.
# record MO_427397414195 (605b68e426ed1e003c28ef69) successfully uploaded.
# record MO_427873955970 (605b68e626ed1e003928ef87) successfully uploaded.
# record MO_430846853065 (605b68ea26ed1e003d28ef6c) successfully uploaded.
# record MO_432861766738 (605b68ed26ed1e003528ef6d) successfully uploaded.
# record MO_444394830472 (605b68f126ed1e002a28efa7) successfully uploaded.
# record MO_450093727396 (605b68f526ed1e003c28ef6d) successfully uploaded.
# record MO_454320668790 (605b68f926ed1e003928ef8b) successfully uploaded.
# record MO_463728687265 (605b68fc26ed1e003d28ef70) successfully uploaded.
# record MO_466741694288 (605b68ff26ed1e003528ef71) successfully uploaded.
# record MO_466808877130 (605b690326ed1e002a28efab) successfully uploaded.
# record MO_468407568810 (605b690626ed1e003c28ef71) successfully uploaded.
# record MO_468686727341 (605b690926ed1e003928ef8f) successfully uploaded.
# record MO_469343973171 (605b690b26ed1e003d28ef74) successfully uploaded.
# record MO_474962707676 (605b690f26ed1e003528ef75) successfully uploaded.
# record MO_475612090600 (605b691226ed1e002a28efaf) successfully uploaded.
# record MO_477506997611 (605b691626ed1e003c28ef75) successfully uploaded.
# record MO_478967255435 (605b691926ed1e003928ef93) successfully uploaded.
# record MO_483480726117 (605b691e26ed1e003d28ef78) successfully uploaded.
# record MO_486450342170 (605b692226ed1e003528ef79) successfully uploaded.
# record MO_489351836217 (605b692626ed1e002a28efb3) successfully uploaded.
# record MO_492310898779 (605b692926ed1e003c28ef79) successfully uploaded.
# record MO_497591319122 (605b692b26ed1e003928ef97) successfully uploaded.
# record MO_500121566391 (605b692e26ed1e003d28ef7c) successfully uploaded.
# record MO_500937681860 (605b693226ed1e003528ef7d) successfully uploaded.
# record MO_503261197030 (605b693826ed1e002a28efb7) successfully uploaded.
# record MO_505250810900 (605b693c26ed1e003c28ef7d) successfully uploaded.
# record MO_514760222899 (605b694026ed1e003928ef9b) successfully uploaded.
# record MO_517338295712 (605b694426ed1e003d28ef80) successfully uploaded.
# record MO_519613893196 (605b694826ed1e003528ef81) successfully uploaded.
# record MO_520569947398 (605b694b26ed1e002a28efbb) successfully uploaded.
# record MO_522239651961 (605b694f26ed1e003c28ef81) successfully uploaded.
# record MO_524392058194 (605b695226ed1e003928ef9f) successfully uploaded.
# record MO_529419924683 (605b695626ed1e003d28ef84) successfully uploaded.
# record MO_533426548156 (605b695926ed1e003528ef85) successfully uploaded.
# record MO_534363225491 (605b695d26ed1e002a28efbf) successfully uploaded.
# record MO_534638645497 (605b696126ed1e003c28ef85) successfully uploaded.
# record MO_535504325462 (605b696526ed1e003928efa3) successfully uploaded.
# record MO_537826574817 (605b696826ed1e003d28ef88) successfully uploaded.
# record MO_545073984441 (605b696b26ed1e003528ef89) successfully uploaded.
# record MO_546673549085 (605b697026ed1e002a28efc3) successfully uploaded.
# record MO_547744193826 (605b697726ed1e003c28ef89) successfully uploaded.
# record MO_549900287421 (605b697a26ed1e003928efa7) successfully uploaded.
# record MO_557267801129 (605b697d26ed1e003d28ef8c) successfully uploaded.
# record MO_557492625287 (605b698126ed1e003528ef8d) successfully uploaded.
# record MO_559016907324 (605b698426ed1e002a28efc7) successfully uploaded.
# record MO_559870613549 (605b698826ed1e003c28ef8d) successfully uploaded.
# record MO_560387080449 (605b698c26ed1e003928efab) successfully uploaded.
# record MO_560940542741 (605b698f26ed1e003d28ef90) successfully uploaded.
# record MO_562200212426 (605b699326ed1e003528ef91) successfully uploaded.
# record MO_566683736730 (605b699626ed1e002a28efcb) successfully uploaded.
# record MO_568033730744 (605b699926ed1e003c28ef91) successfully uploaded.
# record MO_574574915905 (605b699c26ed1e003928efaf) successfully uploaded.
# record MO_577453891941 (605b699f26ed1e003d28ef94) successfully uploaded.
# record MO_579868029681 (605b69a226ed1e003528ef95) successfully uploaded.
# record MO_580571659842 (605b69a626ed1e002a28efcf) successfully uploaded.
# record MO_584345505904 (605b69ab26ed1e003c28ef95) successfully uploaded.
# record MO_587469264453 (605b69ae26ed1e003928efb3) successfully uploaded.
# record MO_592013496703 (605b69b126ed1e003d28ef98) successfully uploaded.
# record MO_593762436933 (605b69b626ed1e003528ef99) successfully uploaded.
# record MO_596300673917 (605b69b926ed1e002a28efd3) successfully uploaded.
# record MO_596436139350 (605b69bf26ed1e003c28ef99) successfully uploaded.
# record MO_600021860456 (605b69c226ed1e003928efb7) successfully uploaded.
# record MO_601539325066 (605b69c526ed1e003d28ef9c) successfully uploaded.
# record MO_604248666067 (605b69c826ed1e003528ef9d) successfully uploaded.
# record MO_609260676108 (605b69cc26ed1e002a28efd7) successfully uploaded.
# record MO_611309973581 (605b69d026ed1e003c28ef9d) successfully uploaded.
# record MO_612061685362 (605b69d326ed1e003928efbb) successfully uploaded.
# record MO_612225165948 (605b69d726ed1e003d28efa0) successfully uploaded.
# record MO_612732924171 (605b69db26ed1e003528efa1) successfully uploaded.
# record MO_616482358807 (605b69de26ed1e002a28efdb) successfully uploaded.
# record MO_616776018688 (605b69e226ed1e003c28efa1) successfully uploaded.
# record MO_618133763375 (605b69e626ed1e003928efbf) successfully uploaded.
# record MO_621445647666 (605b69eb26ed1e003d28efa4) successfully uploaded.
# record MO_623376124862 (605b69ee26ed1e003528efa5) successfully uploaded.
# record MO_626183701337 (605b69f126ed1e002a28efdf) successfully uploaded.
# record MO_626948998302 (605b69f526ed1e003c28efa5) successfully uploaded.
# record MO_636041334617 (605b69f826ed1e003928efc3) successfully uploaded.
# record MO_637493005914 (605b69fb26ed1e003d28efa8) successfully uploaded.
# record MO_642748370624 (605b69fe26ed1e003528efa9) successfully uploaded.
# record MO_646516726498 (605b6a0126ed1e002a28efe3) successfully uploaded.
# record MO_648694198005 (605b6a0426ed1e003c28efa9) successfully uploaded.
# record MO_649864794085 (605b6a0826ed1e003928efc7) successfully uploaded.
# record MO_650279905230 (605b6a0a26ed1e003d28efac) successfully uploaded.
# record MO_651801486679 (605b6a0d26ed1e003528efad) successfully uploaded.
# record MO_655725647552 (605b6a1026ed1e002a28efe7) successfully uploaded.
# record MO_658278549784 (605b6a1326ed1e003c28efad) successfully uploaded.
# record MO_663355627503 (605b6a1626ed1e003928efcb) successfully uploaded.
# record MO_664470114311 (605b6a1926ed1e003d28efb0) successfully uploaded.
# record MO_666348409573 (605b6a1b26ed1e003528efb1) successfully uploaded.
# record MO_666830945336 (605b6a1e26ed1e002a28efeb) successfully uploaded.
# record MO_671124822359 (605b6a2126ed1e003c28efb1) successfully uploaded.
# record MO_673777079812 (605b6a2426ed1e003928efcf) successfully uploaded.
# record MO_676977998912 (605b6a2726ed1e003d28efb4) successfully uploaded.
# record MO_678952612413 (605b6a2a26ed1e003528efb5) successfully uploaded.
# record MO_679329885632 (605b6a2d26ed1e002a28efef) successfully uploaded.
# record MO_681088298208 (605b6a2f26ed1e003c28efb5) successfully uploaded.
# record MO_681640899874 (605b6a3326ed1e003928efd3) successfully uploaded.
# record MO_683890323730 (605b6a3626ed1e003d28efb8) successfully uploaded.
# record MO_684444719999 (605b6a3926ed1e003528efb9) successfully uploaded.
# record MO_692442138123 (605b6a4826ed1e002a28eff3) successfully uploaded.
# record MO_694335101831 (605b6a4b26ed1e003c28efb9) successfully uploaded.
# record MO_698578166685 (605b6a4e26ed1e003928efd7) successfully uploaded.
# record MO_699137396381 (605b6a5126ed1e003d28efbc) successfully uploaded.
# record MO_700541006254 (605b6a5426ed1e003528efbd) successfully uploaded.
# record MO_703849496106 (605b6a5726ed1e002a28eff7) successfully uploaded.
# record MO_706622909913 (605b6a5b26ed1e003c28efbd) successfully uploaded.
# record MO_707981543254 (605b6a5e26ed1e003928efdb) successfully uploaded.
# record MO_708495328010 (605b6a6126ed1e003d28efc0) successfully uploaded.
# record MO_710767216198 (605b6a6426ed1e003528efc1) successfully uploaded.
# record MO_714772088128 (605b6a6726ed1e002a28effb) successfully uploaded.
# record MO_716623333967 (605b6a6926ed1e003c28efc1) successfully uploaded.
# record MO_720819638419 (605b6a6c26ed1e003928efdf) successfully uploaded.
# record MO_721469752060 (605b6a6f26ed1e003d28efc4) successfully uploaded.
# record MO_722489435928 (605b6a7226ed1e003528efc5) successfully uploaded.
# record MO_723456820410 (605b6a7626ed1e002a28efff) successfully uploaded.
# record MO_732106099012 (605b6a7926ed1e003c28efc5) successfully uploaded.
# record MO_737567242631 (605b6a7c26ed1e003928efe3) successfully uploaded.
# record MO_744610363128 (605b6a8026ed1e003d28efc8) successfully uploaded.
# record MO_748534961139 (605b6a8326ed1e003528efc9) successfully uploaded.
# record MO_748636486270 (605b6a8526ed1e002a28f003) successfully uploaded.
# record MO_749732139672 (605b6a8926ed1e003c28efc9) successfully uploaded.
# record MO_751354403791 (605b6a8c26ed1e003928efe7) successfully uploaded.
# record MO_754413982908 (605b6a8f26ed1e003d28efcc) successfully uploaded.
# record MO_754498969542 (605b6a9226ed1e003528efcd) successfully uploaded.
# record MO_757342646688 (605b6a9626ed1e002a28f007) successfully uploaded.
# record MO_758825945924 (605b6a9926ed1e003c28efcd) successfully uploaded.
# record MO_759493141826 (605b6a9e26ed1e003928efeb) successfully uploaded.
# record MO_762798677854 (605b6aa126ed1e003d28efd0) successfully uploaded.
# record MO_763197941039 (605b6aa426ed1e003528efd1) successfully uploaded.
# record MO_764178710049 (605b6aa726ed1e002a28f00b) successfully uploaded.
# record MO_766484508139 (605b6aab26ed1e003c28efd1) successfully uploaded.
# record MO_769582363439 (605b6aaf26ed1e003928efef) successfully uploaded.
# record MO_769632475533 (605b6ab226ed1e003d28efd4) successfully uploaded.
# record MO_771146361182 (605b6ab526ed1e003528efd5) successfully uploaded.
# record MO_781138671863 (605b6ab926ed1e002a28f00f) successfully uploaded.
# record MO_786012902615 (605b6abe26ed1e003c28efd5) successfully uploaded.
# record MO_786496821446 (605b6ace26ed1e003928eff3) successfully uploaded.
# record MO_791486224463 (605b6ad126ed1e003d28efd8) successfully uploaded.
# record MO_793141037706 (605b6ad326ed1e003528efd9) successfully uploaded.
# record MO_796748253903 (605b6ad726ed1e002a28f013) successfully uploaded.
# record MO_799020228312 (605b6adb26ed1e003c28efd9) successfully uploaded.
# record MO_800412945727 (605b6adf26ed1e003928eff7) successfully uploaded.
# record MO_800509458712 (605b6ae226ed1e003d28efdc) successfully uploaded.
# record MO_800536961967 (605b6ae626ed1e003528efdd) successfully uploaded.
# record MO_801083489225 (605b6ae926ed1e002a28f017) successfully uploaded.
# record MO_807997826449 (605b6aec26ed1e003c28efdd) successfully uploaded.
# record MO_808662295149 (605b6aef26ed1e003928effb) successfully uploaded.
# record MO_813575892799 (605b6af326ed1e003d28efe0) successfully uploaded.
# record MO_815057898706 (605b6af726ed1e003528efe1) successfully uploaded.
# record MO_816821594689 (605b6afa26ed1e002a28f01b) successfully uploaded.
# record MO_826591359508 (605b6afd26ed1e003c28efe1) successfully uploaded.
# record MO_831121933939 (605b6b0126ed1e003928efff) successfully uploaded.
# record MO_831380044253 (605b6b0326ed1e003d28efe4) successfully uploaded.
# record MO_831902330215 (605b6b0726ed1e003528efe5) successfully uploaded.
# record MO_832600236922 (605b6b0a26ed1e002a28f01f) successfully uploaded.
# record MO_836927321152 (605b6b0c26ed1e003c28efe5) successfully uploaded.
# record MO_848345414202 (605b6b1026ed1e003928f003) successfully uploaded.
# record MO_848899341753 (605b6b1326ed1e003d28efe8) successfully uploaded.
# record MO_849011491644 (605b6b1626ed1e003528efe9) successfully uploaded.
# record MO_849320763277 (605b6b1926ed1e002a28f023) successfully uploaded.
# record MO_856295952425 (605b6b1c26ed1e003c28efe9) successfully uploaded.
# record MO_856956178669 (605b6b1f26ed1e003928f007) successfully uploaded.
# record MO_857282754307 (605b6b2326ed1e003d28efec) successfully uploaded.
# record MO_859700307573 (605b6b2626ed1e003528efed) successfully uploaded.
# record MO_861114678890 (605b6b2a26ed1e002a28f027) successfully uploaded.
# record MO_861893969202 (605b6b2d26ed1e003c28efed) successfully uploaded.
# record MO_862371677648 (605b6b2f26ed1e003928f00b) successfully uploaded.
# record MO_869330304805 (605b6b3226ed1e003d28eff0) successfully uploaded.
# record MO_874930365376 (605b6b3526ed1e003528eff1) successfully uploaded.
# record MO_876687166519 (605b6b3826ed1e002a28f02b) successfully uploaded.
# record MO_878712978062 (605b6b3c26ed1e003c28eff1) successfully uploaded.
# record MO_880803040302 (605b6b3f26ed1e003928f00f) successfully uploaded.
# record MO_883726743759 (605b6b4426ed1e003d28eff4) successfully uploaded.
# record MO_884343146310 (605b6b4826ed1e003528eff5) successfully uploaded.
# record MO_885079680379 (605b6b4b26ed1e002a28f02f) successfully uploaded.
# record MO_887105884651 (605b6b4e26ed1e003c28eff5) successfully uploaded.
# record MO_887933271505 (605b6b5226ed1e003928f013) successfully uploaded.
# record MO_893505888031 (605b6b5726ed1e003d28eff8) successfully uploaded.
# record MO_894868634445 (605b6b5b26ed1e003528eff9) successfully uploaded.
# record MO_903987585848 (605b6b5f26ed1e002a28f033) successfully uploaded.
# record MO_908110223949 (605b6b6426ed1e003c28eff9) successfully uploaded.
# record MO_908645784389 (605b6b6826ed1e003928f017) successfully uploaded.
# record MO_912636107108 (605b6b6b26ed1e003d28effc) successfully uploaded.
# record MO_912978207512 (605b6b6f26ed1e003528effd) successfully uploaded.
# record MO_913991514986 (605b6b7426ed1e002a28f037) successfully uploaded.
# record MO_914556822329 (605b6b7726ed1e003c28effd) successfully uploaded.
# record MO_922363340570 (605b6b7b26ed1e003928f01b) successfully uploaded.
# record MO_923895531627 (605b6b7e26ed1e003d28f000) successfully uploaded.
# record MO_924630542818 (605b6b8226ed1e003528f001) successfully uploaded.
# record MO_924736622203 (605b6b8626ed1e002a28f03b) successfully uploaded.
# record MO_931672895580 (605b6b8926ed1e003c28f001) successfully uploaded.
# record MO_935641703527 (605b6b8d26ed1e003928f01f) successfully uploaded.
# record MO_937008984446 (605b6b9026ed1e003d28f004) successfully uploaded.
# record MO_942420706858 (605b6b9326ed1e003528f005) successfully uploaded.
# record MO_942551040047 (605b6b9626ed1e002a28f03f) successfully uploaded.
# record MO_945018740343 (605b6b9a26ed1e003c28f005) successfully uploaded.
# record MO_945691923444 (605b6b9d26ed1e003928f023) successfully uploaded.
# record MO_946046425752 (605b6ba026ed1e003d28f008) successfully uploaded.
# record MO_946208788356 (605b6ba426ed1e003528f009) successfully uploaded.
# record MO_946831081299 (605b6ba926ed1e002a28f043) successfully uploaded.
# record MO_947112899505 (605b6bad26ed1e003c28f009) successfully uploaded.
# record MO_950828638160 (605b6bb126ed1e003928f027) successfully uploaded.
# record MO_956135237832 (605b6bb526ed1e003d28f00c) successfully uploaded.
# record MO_958395190627 (605b6bb826ed1e003528f00d) successfully uploaded.
# record MO_958424213898 (605b6bbc26ed1e002a28f047) successfully uploaded.
# record MO_958932894036 (605b6bbf26ed1e003c28f00d) successfully uploaded.
# record MO_959249795837 (605b6bc426ed1e003928f02b) successfully uploaded.
# record MO_960699513424 (605b6bc826ed1e003d28f010) successfully uploaded.
# record MO_964297938209 (605b6bcc26ed1e003528f011) successfully uploaded.
# record MO_966254629593 (605b6bd126ed1e002a28f04b) successfully uploaded.
# record MO_971845881377 (605b6bd426ed1e003c28f011) successfully uploaded.
# record MO_977363131043 (605b6bd926ed1e003928f02f) successfully uploaded.
# record MO_984281096460 (605b6bdc26ed1e003d28f014) successfully uploaded.
# record MO_984358344196 (605b6bde26ed1e003528f015) successfully uploaded.
# record MO_987541074959 (605b6be226ed1e002a28f04f) successfully uploaded.
# record MO_988703794028 (605b6be426ed1e003c28f015) successfully uploaded.
# record MO_993644691224 (605b6be826ed1e003928f033) successfully uploaded.
# record MO_995724792024 (605b6bec26ed1e003d28f018) successfully uploaded.
# record MO_999198119251 (605b6bef26ed1e003528f019) successfully uploaded.
# record MO_999639780744 (605b6bf326ed1e002a28f053) successfully uploaded.
